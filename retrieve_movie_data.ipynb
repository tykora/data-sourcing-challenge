# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import re
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json
from pandas import json_normalize

# %%
# Set environment variables from the .env in the local environment
load_dotenv()

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")

# %%
nyt_api_key
# Out:
# 'GQ6L5nzGGZkpch4dTwYHk8WKM3XAON9Y'

# %%
tmdb_api_key
# Out:
# '31a4563557426ea03e824038071bb9f4'

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL

# %%
res = requests.get(f"{url}q=noodles&api-key={nyt_api_key}").json()
res
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2024 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'abstract': 'Naengmyeon, a filling but light meal, is a necessity for Koreans all over the world.',
#     'web_url': 'https://www.nytimes.com/2023/11/22/magazine/naengmyeon-recipe.html',
#     'snippet': 'Naengmyeon, a filling but light meal, is a necessity for Koreans all over the world.',
#     'lead_paragraph': 'At Olle, the bustling Korean restaurant on East 30th Street in Manhattan, the morning starts with noodle dough. From a mass run through with buckwheat and sweet-potato starch, the noodles are extruded and boiled to order, which is just one of many reasons the naengmyeon at Olle is the best in the city. In less than a second, the doughy tangle drops into a stainless-steel tub of whirling, boiling water. Suddenly animated, the strands swim away like an octopus in flight.',
#     'print_section': 'MM',
#     'print_page': '18',
#     'source': 'The New York Times',
#     'multimedia': [{'rank': 0,
#       'subtype': 'xlarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-articleLarge.jpg',
#       'height': 452,
#       'width': 600,
#       'legacy': {'xlarge': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-articleLarge.jpg',
#        'xlargewidth': 600,
#        'xlargeheight': 452},
#       'subType': 'xlarge',
#       'crop_name': 'articleLarge'},
#      {'rank': 0,
#       'subtype': 'popup',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-popup.jpg',
#       'height': 489,
#       'width': 650,
#       'legacy': {},
#       'subType': 'popup',
#       'crop_name': 'popup'},
#      {'rank': 0,
#       'subtype': 'blog480',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-blog480.jpg',
#       'height': 361,
#       'width': 480,
#       'legacy': {},
#       'subType': 'blog480',
#       'crop_name': 'blog480'},
#      {'rank': 0,
#       'subtype': 'blog533',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-blog533.jpg',
#       'height': 401,
#       'width': 533,
#       'legacy': {},
#       'subType': 'blog533',
#       'crop_name': 'blog533'},
#      {'rank': 0,
#       'subtype': 'blog427',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-blog427.jpg',
#       'height': 322,
#       'width': 427,
#       'legacy': {},
#       'subType': 'blog427',
#       'crop_name': 'blog427'},
#      {'rank': 0,
#       'subtype': 'tmagSF',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-tmagSF.jpg',
#       'height': 273,
#       'width': 362,
#       'legacy': {},
#       'subType': 'tmagSF',
#       'crop_name': 'tmagSF'},
#      {'rank': 0,
#       'subtype': 'tmagArticle',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-tmagArticle.jpg',
#       'height': 446,
#       'width': 592,
#       'legacy': {},
#       'subType': 'tmagArticle',
#       'crop_name': 'tmagArticle'},
#      {'rank': 0,
#       'subtype': 'slide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-slide.jpg',
#       'height': 452,
#       'width': 600,
#       'legacy': {},
#       'subType': 'slide',
#       'crop_name': 'slide'},
#      {'rank': 0,
#       'subtype': 'jumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-jumbo.jpg',
#       'height': 771,
#       'width': 1024,
#       'legacy': {},
#       'subType': 'jumbo',
#       'crop_name': 'jumbo'},
#      {'rank': 0,
#       'subtype': 'superJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-superJumbo.jpg',
#       'height': 1542,
#       'width': 2048,
#       'legacy': {},
#       'subType': 'superJumbo',
#       'crop_name': 'superJumbo'},
#      {'rank': 0,
#       'subtype': 'blog225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-blog225.jpg',
#       'height': 169,
#       'width': 225,
#       'legacy': {},
#       'subType': 'blog225',
#       'crop_name': 'blog225'},
#      {'rank': 0,
#       'subtype': 'master1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-master1050.jpg',
#       'height': 791,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'master1050',
#       'crop_name': 'master1050'},
#      {'rank': 0,
#       'subtype': 'master675',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-master675.jpg',
#       'height': 508,
#       'width': 675,
#       'legacy': {},
#       'subType': 'master675',
#       'crop_name': 'master675'},
#      {'rank': 0,
#       'subtype': 'master495',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-master495.jpg',
#       'height': 373,
#       'width': 495,
#       'legacy': {},
#       'subType': 'master495',
#       'crop_name': 'master495'},
#      {'rank': 0,
#       'subtype': 'master180',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-master180.jpg',
#       'height': 136,
#       'width': 180,
#       'legacy': {},
#       'subType': 'master180',
#       'crop_name': 'master180'},
#      {'rank': 0,
#       'subtype': 'master315',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-master315.jpg',
#       'height': 237,
#       'width': 315,
#       'legacy': {},
#       'subType': 'master315',
#       'crop_name': 'master315'},
#      {'rank': 0,
#       'subtype': 'master768',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-master768.jpg',
#       'height': 578,
#       'width': 768,
#       'legacy': {},
#       'subType': 'master768',
#       'crop_name': 'master768'},
#      {'rank': 0,
#       'subtype': 'thumbnail',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-thumbStandard.jpg',
#       'height': 75,
#       'width': 75,
#       'legacy': {'thumbnail': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-thumbStandard.jpg',
#        'thumbnailwidth': 75,
#        'thumbnailheight': 75},
#       'subType': 'thumbnail',
#       'crop_name': 'thumbStandard'},
#      {'rank': 0,
#       'subtype': 'blogSmallThumb',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-blogSmallThumb.jpg',
#       'height': 50,
#       'width': 50,
#       'legacy': {},
#       'subType': 'blogSmallThumb',
#       'crop_name': 'blogSmallThumb'},
#      {'rank': 0,
#       'subtype': 'thumbLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-thumbLarge.jpg',
#       'height': 150,
#       'width': 150,
#       'legacy': {},
#       'subType': 'thumbLarge',
#       'crop_name': 'thumbLarge'},
#      {'rank': 0,
#       'subtype': 'smallSquare168',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-smallSquare168.jpg',
#       'height': 168,
#       'width': 168,
#       'legacy': {},
#       'subType': 'smallSquare168',
#       'crop_name': 'smallSquare168'},
#      {'rank': 0,
#       'subtype': 'smallSquare252',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-smallSquare252.jpg',
#       'height': 252,
#       'width': 252,
#       'legacy': {},
#       'subType': 'smallSquare252',
#       'crop_name': 'smallSquare252'},
#      {'rank': 0,
#       'subtype': 'square320',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-square320.jpg',
#       'height': 320,
#       'width': 320,
#       'legacy': {},
#       'subType': 'square320',
#       'crop_name': 'square320'},
#      {'rank': 0,
#       'subtype': 'moth',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-moth.jpg',
#       'height': 151,
#       'width': 151,
#       'legacy': {},
#       'subType': 'moth',
#       'crop_name': 'moth'},
#      {'rank': 0,
#       'subtype': 'filmstrip',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-filmstrip.jpg',
#       'height': 190,
#       'width': 190,
#       'legacy': {},
#       'subType': 'filmstrip',
#       'crop_name': 'filmstrip'},
#      {'rank': 0,
#       'subtype': 'square640',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-square640.jpg',
#       'height': 640,
#       'width': 640,
#       'legacy': {},
#       'subType': 'square640',
#       'crop_name': 'square640'},
#      {'rank': 0,
#       'subtype': 'mediumSquare149',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-mediumSquare149.jpg',
#       'height': 149,
#       'width': 149,
#       'legacy': {},
#       'subType': 'mediumSquare149',
#       'crop_name': 'mediumSquare149'},
#      {'rank': 0,
#       'subtype': 'mediumSquareAt3X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-mediumSquareAt3X.jpg',
#       'height': 1542,
#       'width': 1542,
#       'legacy': {},
#       'subType': 'mediumSquareAt3X',
#       'crop_name': 'mediumSquareAt3X'},
#      {'rank': 0,
#       'subtype': 'sfSpan',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-sfSpan.jpg',
#       'height': 263,
#       'width': 395,
#       'legacy': {},
#       'subType': 'sfSpan',
#       'crop_name': 'sfSpan'},
#      {'rank': 0,
#       'subtype': 'largeHorizontal375',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-largeHorizontal375.jpg',
#       'height': 250,
#       'width': 375,
#       'legacy': {},
#       'subType': 'largeHorizontal375',
#       'crop_name': 'largeHorizontal375'},
#      {'rank': 0,
#       'subtype': 'largeHorizontalJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-largeHorizontalJumbo.jpg',
#       'height': 683,
#       'width': 1024,
#       'legacy': {},
#       'subType': 'largeHorizontalJumbo',
#       'crop_name': 'largeHorizontalJumbo'},
#      {'rank': 0,
#       'subtype': 'horizontalMediumAt2X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-horizontalMediumAt2X.jpg',
#       'height': 1366,
#       'width': 2048,
#       'legacy': {},
#       'subType': 'horizontalMediumAt2X',
#       'crop_name': 'horizontalMediumAt2X'},
#      {'rank': 0,
#       'subtype': 'hpLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-hpLarge.jpg',
#       'height': 287,
#       'width': 511,
#       'legacy': {},
#       'subType': 'hpLarge',
#       'crop_name': 'hpLarge'},
#      {'rank': 0,
#       'subtype': 'largeWidescreen573',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-largeWidescreen573.jpg',
#       'height': 322,
#       'width': 573,
#       'legacy': {},
#       'subType': 'largeWidescreen573',
#       'crop_name': 'largeWidescreen573'},
#      {'rank': 0,
#       'subtype': 'largeWidescreen1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-largeWidescreen1050.jpg',
#       'height': 591,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'largeWidescreen1050',
#       'crop_name': 'largeWidescreen1050'},
#      {'rank': 0,
#       'subtype': 'wide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-thumbWide.jpg',
#       'height': 126,
#       'width': 190,
#       'legacy': {'widewidth': 190,
#        'wideheight': 126,
#        'wide': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-thumbWide.jpg'},
#       'subType': 'wide',
#       'crop_name': 'thumbWide'},
#      {'rank': 0,
#       'subtype': 'videoThumb',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-videoThumb.jpg',
#       'height': 50,
#       'width': 75,
#       'legacy': {},
#       'subType': 'videoThumb',
#       'crop_name': 'videoThumb'},
#      {'rank': 0,
#       'subtype': 'videoLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-videoLarge.jpg',
#       'height': 507,
#       'width': 768,
#       'legacy': {},
#       'subType': 'videoLarge',
#       'crop_name': 'videoLarge'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo210',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-mediumThreeByTwo210.jpg',
#       'height': 140,
#       'width': 210,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo210',
#       'crop_name': 'mediumThreeByTwo210'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-mediumThreeByTwo225.jpg',
#       'height': 150,
#       'width': 225,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo225',
#       'crop_name': 'mediumThreeByTwo225'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo440',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-mediumThreeByTwo440.jpg',
#       'height': 293,
#       'width': 440,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo440',
#       'crop_name': 'mediumThreeByTwo440'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo252',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-mediumThreeByTwo252.jpg',
#       'height': 168,
#       'width': 252,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo252',
#       'crop_name': 'mediumThreeByTwo252'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo378',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-mediumThreeByTwo378.jpg',
#       'height': 252,
#       'width': 378,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo378',
#       'crop_name': 'mediumThreeByTwo378'},
#      {'rank': 0,
#       'subtype': 'threeByTwoLargeAt2X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-threeByTwoLargeAt2X.jpg',
#       'height': 1366,
#       'width': 2048,
#       'legacy': {},
#       'subType': 'threeByTwoLargeAt2X',
#       'crop_name': 'threeByTwoLargeAt2X'},
#      {'rank': 0,
#       'subtype': 'threeByTwoMediumAt2X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-threeByTwoMediumAt2X.jpg',
#       'height': 1000,
#       'width': 1500,
#       'legacy': {},
#       'subType': 'threeByTwoMediumAt2X',
#       'crop_name': 'threeByTwoMediumAt2X'},
#      {'rank': 0,
#       'subtype': 'threeByTwoSmallAt2X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-threeByTwoSmallAt2X.jpg',
#       'height': 400,
#       'width': 600,
#       'legacy': {},
#       'subType': 'threeByTwoSmallAt2X',
#       'crop_name': 'threeByTwoSmallAt2X'},
#      {'rank': 0,
#       'subtype': 'articleInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-articleInline.jpg',
#       'height': 143,
#       'width': 190,
#       'legacy': {},
#       'subType': 'articleInline',
#       'crop_name': 'articleInline'},
#      {'rank': 0,
#       'subtype': 'hpSmall',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-hpSmall.jpg',
#       'height': 123,
#       'width': 163,
#       'legacy': {},
#       'subType': 'hpSmall',
#       'crop_name': 'hpSmall'},
#      {'rank': 0,
#       'subtype': 'blogSmallInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-blogSmallInline.jpg',
#       'height': 114,
#       'width': 151,
#       'legacy': {},
#       'subType': 'blogSmallInline',
#       'crop_name': 'blogSmallInline'},
#      {'rank': 0,
#       'subtype': 'mediumFlexible177',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-mediumFlexible177.jpg',
#       'height': 133,
#       'width': 177,
#       'legacy': {},
#       'subType': 'mediumFlexible177',
#       'crop_name': 'mediumFlexible177'},
#      {'rank': 0,
#       'subtype': 'videoSmall',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-videoSmall.jpg',
#       'height': 281,
#       'width': 500,
#       'legacy': {},
#       'subType': 'videoSmall',
#       'crop_name': 'videoSmall'},
#      {'rank': 0,
#       'subtype': 'videoHpMedium',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-videoHpMedium.jpg',
#       'height': 211,
#       'width': 375,
#       'legacy': {},
#       'subType': 'videoHpMedium',
#       'crop_name': 'videoHpMedium'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine600',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-videoSixteenByNine600.jpg',
#       'height': 338,
#       'width': 600,
#       'legacy': {},
#       'subType': 'videoSixteenByNine600',
#       'crop_name': 'videoSixteenByNine600'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine540',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-videoSixteenByNine540.jpg',
#       'height': 304,
#       'width': 540,
#       'legacy': {},
#       'subType': 'videoSixteenByNine540',
#       'crop_name': 'videoSixteenByNine540'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine495',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-videoSixteenByNine495.jpg',
#       'height': 278,
#       'width': 495,
#       'legacy': {},
#       'subType': 'videoSixteenByNine495',
#       'crop_name': 'videoSixteenByNine495'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine390',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-videoSixteenByNine390.jpg',
#       'height': 219,
#       'width': 390,
#       'legacy': {},
#       'subType': 'videoSixteenByNine390',
#       'crop_name': 'videoSixteenByNine390'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-videoSixteenByNine1050.jpg',
#       'height': 591,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'videoSixteenByNine1050',
#       'crop_name': 'videoSixteenByNine1050'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine480',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-videoSixteenByNine480.jpg',
#       'height': 270,
#       'width': 480,
#       'legacy': {},
#       'subType': 'videoSixteenByNine480',
#       'crop_name': 'videoSixteenByNine480'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine310',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-videoSixteenByNine310.jpg',
#       'height': 174,
#       'width': 310,
#       'legacy': {},
#       'subType': 'videoSixteenByNine310',
#       'crop_name': 'videoSixteenByNine310'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-videoSixteenByNine225.jpg',
#       'height': 126,
#       'width': 225,
#       'legacy': {},
#       'subType': 'videoSixteenByNine225',
#       'crop_name': 'videoSixteenByNine225'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine96',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-videoSixteenByNine96.jpg',
#       'height': 54,
#       'width': 96,
#       'legacy': {},
#       'subType': 'videoSixteenByNine96',
#       'crop_name': 'videoSixteenByNine96'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine768',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-videoSixteenByNine768.jpg',
#       'height': 432,
#       'width': 768,
#       'legacy': {},
#       'subType': 'videoSixteenByNine768',
#       'crop_name': 'videoSixteenByNine768'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine150',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-videoSixteenByNine150.jpg',
#       'height': 84,
#       'width': 150,
#       'legacy': {},
#       'subType': 'videoSixteenByNine150',
#       'crop_name': 'videoSixteenByNine150'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNineJumbo1600',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-videoSixteenByNineJumbo1600.jpg',
#       'height': 900,
#       'width': 1600,
#       'legacy': {},
#       'subType': 'videoSixteenByNineJumbo1600',
#       'crop_name': 'videoSixteenByNineJumbo1600'},
#      {'rank': 0,
#       'subtype': 'miniMoth',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-miniMoth.jpg',
#       'height': 70,
#       'width': 151,
#       'legacy': {},
#       'subType': 'miniMoth',
#       'crop_name': 'miniMoth'},
#      {'rank': 0,
#       'subtype': 'windowsTile336H',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-windowsTile336H.jpg',
#       'height': 336,
#       'width': 694,
#       'legacy': {},
#       'subType': 'windowsTile336H',
#       'crop_name': 'windowsTile336H'},
#      {'rank': 0,
#       'subtype': 'videoFifteenBySeven1305',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-videoFifteenBySeven1305.jpg',
#       'height': 609,
#       'width': 1305,
#       'legacy': {},
#       'subType': 'videoFifteenBySeven1305',
#       'crop_name': 'videoFifteenBySeven1305'},
#      {'rank': 0,
#       'subtype': 'facebookJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-facebookJumbo.jpg',
#       'height': 550,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'facebookJumbo',
#       'crop_name': 'facebookJumbo'},
#      {'rank': 0,
#       'subtype': 'watch308',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-watch308.jpg',
#       'height': 348,
#       'width': 312,
#       'legacy': {},
#       'subType': 'watch308',
#       'crop_name': 'watch308'},
#      {'rank': 0,
#       'subtype': 'watch268',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-watch268.jpg',
#       'height': 303,
#       'width': 272,
#       'legacy': {},
#       'subType': 'watch268',
#       'crop_name': 'watch268'},
#      {'rank': 0,
#       'subtype': 'verticalTwoByThree735',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-verticalTwoByThree735.jpg',
#       'height': 1103,
#       'width': 735,
#       'legacy': {},
#       'subType': 'verticalTwoByThree735',
#       'crop_name': 'verticalTwoByThree735'},
#      {'rank': 0,
#       'subtype': 'mobileMasterAt3x',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/26/magazine/26mag-Eat/26mag-Eat-mobileMasterAt3x.jpg',
#       'height': 1355,
#       'width': 1800,
#       'legacy': {},
#       'subType': 'mobileMasterAt3x',
#       'crop_name': 'mobileMasterAt3x'}],
#     'headline': {'main': 'You Won’t Just Love These Cold Noodles. You’ll Need Them.',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'A Singular Slurp: The secret ingredient to this rich, beefy noodle dish? Water.',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Noodles',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Beef', 'rank': 2, 'major': 'N'},
#      {'name': 'subject', 'value': 'Recipes', 'rank': 3, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Cooking and Cookbooks',
#       'rank': 4,
#       'major': 'N'}],
#     'pub_date': '2023-11-22T14:34:59+0000',
#     'document_type': 'article',
#     'news_desk': 'Magazine',
#     'section_name': 'Magazine',
#     'byline': {'original': 'By Eric Kim',
#      'person': [{'firstname': 'Eric',
#        'middlename': None,
#        'lastname': 'Kim',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/9b44945c-8777-5d7e-bce5-5660cdef4dd0',
#     'word_count': 745,
#     'uri': 'nyt://article/9b44945c-8777-5d7e-bce5-5660cdef4dd0'},
#    {'abstract': 'In Manhattan, Brooklyn and Queens you’ll find superlative versions of prawn mee, mohinga and more.',
#     'web_url': 'https://www.nytimes.com/2023/11/09/dining/8-excellent-asian-noodle-soups-in-three-boroughs.html',
#     'snippet': 'In Manhattan, Brooklyn and Queens you’ll find superlative versions of prawn mee, mohinga and more.',
#     'lead_paragraph': 'Last week I wrote about soup, which I suggested is not as popular as it once was, possibly because it is not cut out for the age of share plates.',
#     'print_section': 'D',
#     'print_page': '2',
#     'source': 'The New York Times',
#     'multimedia': [{'rank': 0,
#       'subtype': 'xlarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-articleLarge.jpg',
#       'height': 399,
#       'width': 600,
#       'legacy': {'xlarge': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-articleLarge.jpg',
#        'xlargewidth': 600,
#        'xlargeheight': 399},
#       'subType': 'xlarge',
#       'crop_name': 'articleLarge'},
#      {'rank': 0,
#       'subtype': 'popup',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-popup.jpg',
#       'height': 433,
#       'width': 650,
#       'legacy': {},
#       'subType': 'popup',
#       'crop_name': 'popup'},
#      {'rank': 0,
#       'subtype': 'blog480',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-blog480.jpg',
#       'height': 319,
#       'width': 480,
#       'legacy': {},
#       'subType': 'blog480',
#       'crop_name': 'blog480'},
#      {'rank': 0,
#       'subtype': 'blog533',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-blog533.jpg',
#       'height': 355,
#       'width': 533,
#       'legacy': {},
#       'subType': 'blog533',
#       'crop_name': 'blog533'},
#      {'rank': 0,
#       'subtype': 'blog427',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-blog427.jpg',
#       'height': 284,
#       'width': 427,
#       'legacy': {},
#       'subType': 'blog427',
#       'crop_name': 'blog427'},
#      {'rank': 0,
#       'subtype': 'tmagSF',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-tmagSF.jpg',
#       'height': 241,
#       'width': 362,
#       'legacy': {},
#       'subType': 'tmagSF',
#       'crop_name': 'tmagSF'},
#      {'rank': 0,
#       'subtype': 'tmagArticle',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-tmagArticle.jpg',
#       'height': 394,
#       'width': 592,
#       'legacy': {},
#       'subType': 'tmagArticle',
#       'crop_name': 'tmagArticle'},
#      {'rank': 0,
#       'subtype': 'slide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-slide.jpg',
#       'height': 399,
#       'width': 600,
#       'legacy': {},
#       'subType': 'slide',
#       'crop_name': 'slide'},
#      {'rank': 0,
#       'subtype': 'jumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-jumbo.jpg',
#       'height': 681,
#       'width': 1024,
#       'legacy': {},
#       'subType': 'jumbo',
#       'crop_name': 'jumbo'},
#      {'rank': 0,
#       'subtype': 'superJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-superJumbo.jpg',
#       'height': 1363,
#       'width': 2048,
#       'legacy': {},
#       'subType': 'superJumbo',
#       'crop_name': 'superJumbo'},
#      {'rank': 0,
#       'subtype': 'blog225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-blog225.jpg',
#       'height': 150,
#       'width': 225,
#       'legacy': {},
#       'subType': 'blog225',
#       'crop_name': 'blog225'},
#      {'rank': 0,
#       'subtype': 'master1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-master1050.jpg',
#       'height': 699,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'master1050',
#       'crop_name': 'master1050'},
#      {'rank': 0,
#       'subtype': 'master675',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-master675.jpg',
#       'height': 449,
#       'width': 675,
#       'legacy': {},
#       'subType': 'master675',
#       'crop_name': 'master675'},
#      {'rank': 0,
#       'subtype': 'master495',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-master495.jpg',
#       'height': 329,
#       'width': 495,
#       'legacy': {},
#       'subType': 'master495',
#       'crop_name': 'master495'},
#      {'rank': 0,
#       'subtype': 'master180',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-master180.jpg',
#       'height': 120,
#       'width': 180,
#       'legacy': {},
#       'subType': 'master180',
#       'crop_name': 'master180'},
#      {'rank': 0,
#       'subtype': 'master315',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-master315.jpg',
#       'height': 210,
#       'width': 315,
#       'legacy': {},
#       'subType': 'master315',
#       'crop_name': 'master315'},
#      {'rank': 0,
#       'subtype': 'master768',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-master768.jpg',
#       'height': 511,
#       'width': 768,
#       'legacy': {},
#       'subType': 'master768',
#       'crop_name': 'master768'},
#      {'rank': 0,
#       'subtype': 'thumbnail',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-thumbStandard.jpg',
#       'height': 75,
#       'width': 75,
#       'legacy': {'thumbnail': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-thumbStandard.jpg',
#        'thumbnailwidth': 75,
#        'thumbnailheight': 75},
#       'subType': 'thumbnail',
#       'crop_name': 'thumbStandard'},
#      {'rank': 0,
#       'subtype': 'blogSmallThumb',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-blogSmallThumb.jpg',
#       'height': 50,
#       'width': 50,
#       'legacy': {},
#       'subType': 'blogSmallThumb',
#       'crop_name': 'blogSmallThumb'},
#      {'rank': 0,
#       'subtype': 'thumbLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-thumbLarge.jpg',
#       'height': 150,
#       'width': 150,
#       'legacy': {},
#       'subType': 'thumbLarge',
#       'crop_name': 'thumbLarge'},
#      {'rank': 0,
#       'subtype': 'smallSquare168',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-smallSquare168.jpg',
#       'height': 168,
#       'width': 168,
#       'legacy': {},
#       'subType': 'smallSquare168',
#       'crop_name': 'smallSquare168'},
#      {'rank': 0,
#       'subtype': 'smallSquare252',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-smallSquare252.jpg',
#       'height': 252,
#       'width': 252,
#       'legacy': {},
#       'subType': 'smallSquare252',
#       'crop_name': 'smallSquare252'},
#      {'rank': 0,
#       'subtype': 'square320',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-square320.jpg',
#       'height': 320,
#       'width': 320,
#       'legacy': {},
#       'subType': 'square320',
#       'crop_name': 'square320'},
#      {'rank': 0,
#       'subtype': 'moth',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-moth.jpg',
#       'height': 151,
#       'width': 151,
#       'legacy': {},
#       'subType': 'moth',
#       'crop_name': 'moth'},
#      {'rank': 0,
#       'subtype': 'filmstrip',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-filmstrip.jpg',
#       'height': 190,
#       'width': 190,
#       'legacy': {},
#       'subType': 'filmstrip',
#       'crop_name': 'filmstrip'},
#      {'rank': 0,
#       'subtype': 'square640',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-square640.jpg',
#       'height': 640,
#       'width': 640,
#       'legacy': {},
#       'subType': 'square640',
#       'crop_name': 'square640'},
#      {'rank': 0,
#       'subtype': 'mediumSquare149',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-mediumSquare149.jpg',
#       'height': 149,
#       'width': 149,
#       'legacy': {},
#       'subType': 'mediumSquare149',
#       'crop_name': 'mediumSquare149'},
#      {'rank': 0,
#       'subtype': 'mediumSquareAt3X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-mediumSquareAt3X.jpg',
#       'height': 1800,
#       'width': 1800,
#       'legacy': {},
#       'subType': 'mediumSquareAt3X',
#       'crop_name': 'mediumSquareAt3X'},
#      {'rank': 0,
#       'subtype': 'sfSpan',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-sfSpan.jpg',
#       'height': 263,
#       'width': 395,
#       'legacy': {},
#       'subType': 'sfSpan',
#       'crop_name': 'sfSpan'},
#      {'rank': 0,
#       'subtype': 'largeHorizontal375',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-largeHorizontal375.jpg',
#       'height': 250,
#       'width': 375,
#       'legacy': {},
#       'subType': 'largeHorizontal375',
#       'crop_name': 'largeHorizontal375'},
#      {'rank': 0,
#       'subtype': 'largeHorizontalJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-largeHorizontalJumbo.jpg',
#       'height': 683,
#       'width': 1024,
#       'legacy': {},
#       'subType': 'largeHorizontalJumbo',
#       'crop_name': 'largeHorizontalJumbo'},
#      {'rank': 0,
#       'subtype': 'horizontalMediumAt2X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-horizontalMediumAt2X.jpg',
#       'height': 2832,
#       'width': 4248,
#       'legacy': {},
#       'subType': 'horizontalMediumAt2X',
#       'crop_name': 'horizontalMediumAt2X'},
#      {'rank': 0,
#       'subtype': 'hpLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-hpLarge.jpg',
#       'height': 287,
#       'width': 511,
#       'legacy': {},
#       'subType': 'hpLarge',
#       'crop_name': 'hpLarge'},
#      {'rank': 0,
#       'subtype': 'largeWidescreen573',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-largeWidescreen573.jpg',
#       'height': 322,
#       'width': 573,
#       'legacy': {},
#       'subType': 'largeWidescreen573',
#       'crop_name': 'largeWidescreen573'},
#      {'rank': 0,
#       'subtype': 'largeWidescreen1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-largeWidescreen1050.jpg',
#       'height': 591,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'largeWidescreen1050',
#       'crop_name': 'largeWidescreen1050'},
#      {'rank': 0,
#       'subtype': 'wide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-thumbWide.jpg',
#       'height': 126,
#       'width': 190,
#       'legacy': {'widewidth': 190,
#        'wideheight': 126,
#        'wide': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-thumbWide.jpg'},
#       'subType': 'wide',
#       'crop_name': 'thumbWide'},
#      {'rank': 0,
#       'subtype': 'videoThumb',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-videoThumb.jpg',
#       'height': 50,
#       'width': 75,
#       'legacy': {},
#       'subType': 'videoThumb',
#       'crop_name': 'videoThumb'},
#      {'rank': 0,
#       'subtype': 'videoLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-videoLarge.jpg',
#       'height': 507,
#       'width': 768,
#       'legacy': {},
#       'subType': 'videoLarge',
#       'crop_name': 'videoLarge'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo210',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-mediumThreeByTwo210.jpg',
#       'height': 140,
#       'width': 210,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo210',
#       'crop_name': 'mediumThreeByTwo210'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-mediumThreeByTwo225.jpg',
#       'height': 150,
#       'width': 225,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo225',
#       'crop_name': 'mediumThreeByTwo225'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo440',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-mediumThreeByTwo440.jpg',
#       'height': 293,
#       'width': 440,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo440',
#       'crop_name': 'mediumThreeByTwo440'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo252',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-mediumThreeByTwo252.jpg',
#       'height': 168,
#       'width': 252,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo252',
#       'crop_name': 'mediumThreeByTwo252'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo378',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-mediumThreeByTwo378.jpg',
#       'height': 252,
#       'width': 378,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo378',
#       'crop_name': 'mediumThreeByTwo378'},
#      {'rank': 0,
#       'subtype': 'threeByTwoLargeAt2X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-threeByTwoLargeAt2X.jpg',
#       'height': 2832,
#       'width': 4248,
#       'legacy': {},
#       'subType': 'threeByTwoLargeAt2X',
#       'crop_name': 'threeByTwoLargeAt2X'},
#      {'rank': 0,
#       'subtype': 'threeByTwoMediumAt2X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-threeByTwoMediumAt2X.jpg',
#       'height': 1000,
#       'width': 1500,
#       'legacy': {},
#       'subType': 'threeByTwoMediumAt2X',
#       'crop_name': 'threeByTwoMediumAt2X'},
#      {'rank': 0,
#       'subtype': 'threeByTwoSmallAt2X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-threeByTwoSmallAt2X.jpg',
#       'height': 400,
#       'width': 600,
#       'legacy': {},
#       'subType': 'threeByTwoSmallAt2X',
#       'crop_name': 'threeByTwoSmallAt2X'},
#      {'rank': 0,
#       'subtype': 'articleInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-articleInline.jpg',
#       'height': 126,
#       'width': 190,
#       'legacy': {},
#       'subType': 'articleInline',
#       'crop_name': 'articleInline'},
#      {'rank': 0,
#       'subtype': 'hpSmall',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-hpSmall.jpg',
#       'height': 108,
#       'width': 163,
#       'legacy': {},
#       'subType': 'hpSmall',
#       'crop_name': 'hpSmall'},
#      {'rank': 0,
#       'subtype': 'blogSmallInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-blogSmallInline.jpg',
#       'height': 100,
#       'width': 151,
#       'legacy': {},
#       'subType': 'blogSmallInline',
#       'crop_name': 'blogSmallInline'},
#      {'rank': 0,
#       'subtype': 'mediumFlexible177',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-mediumFlexible177.jpg',
#       'height': 118,
#       'width': 177,
#       'legacy': {},
#       'subType': 'mediumFlexible177',
#       'crop_name': 'mediumFlexible177'},
#      {'rank': 0,
#       'subtype': 'videoSmall',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-videoSmall.jpg',
#       'height': 281,
#       'width': 500,
#       'legacy': {},
#       'subType': 'videoSmall',
#       'crop_name': 'videoSmall'},
#      {'rank': 0,
#       'subtype': 'videoHpMedium',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-videoHpMedium.jpg',
#       'height': 211,
#       'width': 375,
#       'legacy': {},
#       'subType': 'videoHpMedium',
#       'crop_name': 'videoHpMedium'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine600',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-videoSixteenByNine600.jpg',
#       'height': 338,
#       'width': 600,
#       'legacy': {},
#       'subType': 'videoSixteenByNine600',
#       'crop_name': 'videoSixteenByNine600'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine540',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-videoSixteenByNine540.jpg',
#       'height': 304,
#       'width': 540,
#       'legacy': {},
#       'subType': 'videoSixteenByNine540',
#       'crop_name': 'videoSixteenByNine540'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine495',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-videoSixteenByNine495.jpg',
#       'height': 278,
#       'width': 495,
#       'legacy': {},
#       'subType': 'videoSixteenByNine495',
#       'crop_name': 'videoSixteenByNine495'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine390',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2023/11/15/multimedia/15wte-noodle-soup1-bpwq/09wte-noodle-soup1-bpwq-videoSixteenByNine390.jpg',
#       'height': 219,
#       'width': 390,
#       'legacy': {},
# ...
#       'crop_name': 'superJumbo'},
#      {'rank': 0,
#       'subtype': 'master495',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2011/09/28/dining/28UNDER/28UNDER-master495-v2.jpg',
#       'height': 742,
#       'width': 495,
#       'legacy': {},
#       'subType': 'master495',
#       'crop_name': 'master495'},
#      {'rank': 0,
#       'subtype': 'master315',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2011/09/28/dining/28UNDER/28UNDER-master315-v2.jpg',
#       'height': 472,
#       'width': 315,
#       'legacy': {},
#       'subType': 'master315',
#       'crop_name': 'master315'},
#      {'rank': 0,
#       'subtype': 'square320',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2011/09/28/dining/28UNDER/28UNDER-square320-v2.jpg',
#       'height': 320,
#       'width': 320,
#       'legacy': {},
#       'subType': 'square320',
#       'crop_name': 'square320'},
#      {'rank': 0,
#       'subtype': 'filmstrip',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2011/09/28/dining/28UNDER/28UNDER-filmstrip-v2.jpg',
#       'height': 190,
#       'width': 190,
#       'legacy': {},
#       'subType': 'filmstrip',
#       'crop_name': 'filmstrip'},
#      {'rank': 0,
#       'subtype': 'square640',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2011/09/28/dining/28UNDER/28UNDER-square640-v2.jpg',
#       'height': 640,
#       'width': 640,
#       'legacy': {},
#       'subType': 'square640',
#       'crop_name': 'square640'},
#      {'rank': 0,
#       'subtype': 'moth',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2011/09/28/dining/28UNDER/28UNDER-moth-v2.jpg',
#       'height': 151,
#       'width': 151,
#       'legacy': {},
#       'subType': 'moth',
#       'crop_name': 'moth'},
#      {'rank': 0,
#       'subtype': 'mediumSquare149',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2011/09/28/dining/28UNDER/28UNDER-mediumSquare149-v2.jpg',
#       'height': 149,
#       'width': 149,
#       'legacy': {},
#       'subType': 'mediumSquare149',
#       'crop_name': 'mediumSquare149'},
#      {'rank': 0,
#       'subtype': 'articleInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2011/09/28/dining/28UNDER/28UNDER-articleInline-v3.jpg',
#       'height': 285,
#       'width': 190,
#       'legacy': {},
#       'subType': 'articleInline',
#       'crop_name': 'articleInline'},
#      {'rank': 0,
#       'subtype': 'hpSmall',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2011/09/28/dining/28UNDER/28UNDER-hpSmall-v2.jpg',
#       'height': 244,
#       'width': 163,
#       'legacy': {},
#       'subType': 'hpSmall',
#       'crop_name': 'hpSmall'},
#      {'rank': 0,
#       'subtype': 'blogSmallInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2011/09/28/dining/28UNDER/28UNDER-blogSmallInline-v2.jpg',
#       'height': 226,
#       'width': 151,
#       'legacy': {},
#       'subType': 'blogSmallInline',
#       'crop_name': 'blogSmallInline'},
#      {'rank': 0,
#       'subtype': 'mediumFlexible177',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2011/09/28/dining/28UNDER/28UNDER-mediumFlexible177-v2.jpg',
#       'height': 265,
#       'width': 177,
#       'legacy': {},
#       'subType': 'mediumFlexible177',
#       'crop_name': 'mediumFlexible177'},
#      {'rank': 0,
#       'subtype': 'sfSpan',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2011/09/28/dining/28UNDER/28UNDER-sfSpan-v2.jpg',
#       'height': 264,
#       'width': 395,
#       'legacy': {},
#       'subType': 'sfSpan',
#       'crop_name': 'sfSpan'},
#      {'rank': 0,
#       'subtype': 'largeHorizontalJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2011/09/28/dining/28UNDER/28UNDER-largeHorizontalJumbo-v2.jpg',
#       'height': 456,
#       'width': 683,
#       'legacy': {},
#       'subType': 'largeHorizontalJumbo',
#       'crop_name': 'largeHorizontalJumbo'},
#      {'rank': 0,
#       'subtype': 'largeHorizontal375',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2011/09/28/dining/28UNDER/28UNDER-largeHorizontal375-v2.jpg',
#       'height': 250,
#       'width': 375,
#       'legacy': {},
#       'subType': 'largeHorizontal375',
#       'crop_name': 'largeHorizontal375'},
#      {'rank': 0,
#       'subtype': 'hpLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2011/09/28/dining/28UNDER/28UNDER-hpLarge-v2.jpg',
#       'height': 287,
#       'width': 511,
#       'legacy': {},
#       'subType': 'hpLarge',
#       'crop_name': 'hpLarge'},
#      {'rank': 0,
#       'subtype': 'largeWidescreen573',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2011/09/28/dining/28UNDER/28UNDER-largeWidescreen573-v2.jpg',
#       'height': 322,
#       'width': 573,
#       'legacy': {},
#       'subType': 'largeWidescreen573',
#       'crop_name': 'largeWidescreen573'},
#      {'rank': 0,
#       'subtype': 'videoSmall',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2011/09/28/dining/28UNDER/28UNDER-videoSmall-v2.jpg',
#       'height': 281,
#       'width': 500,
#       'legacy': {},
#       'subType': 'videoSmall',
#       'crop_name': 'videoSmall'},
#      {'rank': 0,
#       'subtype': 'videoHpMedium',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2011/09/28/dining/28UNDER/28UNDER-videoHpMedium-v2.jpg',
#       'height': 211,
#       'width': 375,
#       'legacy': {},
#       'subType': 'videoHpMedium',
#       'crop_name': 'videoHpMedium'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine600',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2011/09/28/dining/28UNDER/28UNDER-videoSixteenByNine600-v2.jpg',
#       'height': 338,
#       'width': 600,
#       'legacy': {},
#       'subType': 'videoSixteenByNine600',
#       'crop_name': 'videoSixteenByNine600'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine540',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2011/09/28/dining/28UNDER/28UNDER-videoSixteenByNine540-v2.jpg',
#       'height': 304,
#       'width': 540,
#       'legacy': {},
#       'subType': 'videoSixteenByNine540',
#       'crop_name': 'videoSixteenByNine540'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine495',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2011/09/28/dining/28UNDER/28UNDER-videoSixteenByNine495-v2.jpg',
#       'height': 278,
#       'width': 495,
#       'legacy': {},
#       'subType': 'videoSixteenByNine495',
#       'crop_name': 'videoSixteenByNine495'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine390',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2011/09/28/dining/28UNDER/28UNDER-videoSixteenByNine390-v2.jpg',
#       'height': 219,
#       'width': 390,
#       'legacy': {},
#       'subType': 'videoSixteenByNine390',
#       'crop_name': 'videoSixteenByNine390'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine480',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2011/09/28/dining/28UNDER/28UNDER-videoSixteenByNine480-v2.jpg',
#       'height': 270,
#       'width': 480,
#       'legacy': {},
#       'subType': 'videoSixteenByNine480',
#       'crop_name': 'videoSixteenByNine480'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine310',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2011/09/28/dining/28UNDER/28UNDER-videoSixteenByNine310-v2.jpg',
#       'height': 174,
#       'width': 310,
#       'legacy': {},
#       'subType': 'videoSixteenByNine310',
#       'crop_name': 'videoSixteenByNine310'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2011/09/28/dining/28UNDER/28UNDER-videoSixteenByNine225-v2.jpg',
#       'height': 126,
#       'width': 225,
#       'legacy': {},
#       'subType': 'videoSixteenByNine225',
#       'crop_name': 'videoSixteenByNine225'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine96',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2011/09/28/dining/28UNDER/28UNDER-videoSixteenByNine96-v2.jpg',
#       'height': 54,
#       'width': 96,
#       'legacy': {},
#       'subType': 'videoSixteenByNine96',
#       'crop_name': 'videoSixteenByNine96'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine150',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2011/09/28/dining/28UNDER/28UNDER-videoSixteenByNine150-v2.jpg',
#       'height': 84,
#       'width': 150,
#       'legacy': {},
#       'subType': 'videoSixteenByNine150',
#       'crop_name': 'videoSixteenByNine150'},
#      {'rank': 0,
#       'subtype': 'thumbnail',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2011/09/28/dining/28UNDER/28UNDER-thumbStandard-v3.jpg',
#       'height': 75,
#       'width': 75,
#       'legacy': {'thumbnail': 'images/2011/09/28/dining/28UNDER/28UNDER-thumbStandard-v3.jpg',
#        'thumbnailwidth': 75,
#        'thumbnailheight': 75},
#       'subType': 'thumbnail',
#       'crop_name': 'thumbStandard'},
#      {'rank': 0,
#       'subtype': 'thumbLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2011/09/28/dining/28UNDER/28UNDER-thumbLarge-v2.jpg',
#       'height': 150,
#       'width': 150,
#       'legacy': {},
#       'subType': 'thumbLarge',
#       'crop_name': 'thumbLarge'},
#      {'rank': 0,
#       'subtype': 'smallSquare252',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2011/09/28/dining/28UNDER/28UNDER-smallSquare252-v2.jpg',
#       'height': 252,
#       'width': 252,
#       'legacy': {},
#       'subType': 'smallSquare252',
#       'crop_name': 'smallSquare252'},
#      {'rank': 0,
#       'subtype': 'blogSmallThumb',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2011/09/28/dining/28UNDER/28UNDER-blogSmallThumb-v2.jpg',
#       'height': 50,
#       'width': 50,
#       'legacy': {},
#       'subType': 'blogSmallThumb',
#       'crop_name': 'blogSmallThumb'},
#      {'rank': 0,
#       'subtype': 'smallSquare168',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2011/09/28/dining/28UNDER/28UNDER-smallSquare168-v2.jpg',
#       'height': 168,
#       'width': 168,
#       'legacy': {},
#       'subType': 'smallSquare168',
#       'crop_name': 'smallSquare168'}],
#     'headline': {'main': 'Wrap Yourself in Noodles',
#      'kicker': '$25 and Under',
#      'content_kicker': None,
#      'print_headline': 'Wrap Yourself In Noodles',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Noodles',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Restaurants', 'rank': 2, 'major': 'N'},
#      {'name': 'glocations',
#       'value': 'Midtown Area (NYC)',
#       'rank': 3,
#       'major': 'N'}],
#     'pub_date': '2011-09-27T21:46:10+0000',
#     'document_type': 'article',
#     'news_desk': 'Dining',
#     'section_name': 'Food',
#     'subsection_name': 'Dining & Wine',
#     'byline': {'original': 'By Julia Moskin',
#      'person': [{'firstname': 'Julia',
#        'middlename': None,
#        'lastname': 'Moskin',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'Review',
#     '_id': 'nyt://article/999f0470-6e60-565d-bb11-0e0eb53f9799',
#     'word_count': 542,
#     'uri': 'nyt://article/999f0470-6e60-565d-bb11-0e0eb53f9799'},
#    {'abstract': 'Peter Meehan reviews Momofuku Noodle Bar in East Village; photo (M)',
#     'web_url': 'https://www.nytimes.com/2005/04/13/dining/reviews/at-a-noodle-bar-the-noodles-play-catchup.html',
#     'snippet': 'Peter Meehan reviews Momofuku Noodle Bar in East Village; photo (M)',
#     'lead_paragraph': "GOOD restaurants don't always start off at the top of their game. The food steadily improves, servers hit their stride and the kitchen settles into a working rhythm. It can be nothing short of thrilling to watch one shake off its early awkwardness and come into its own.",
#     'print_section': 'F',
#     'print_page': '11',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'At a Noodle Bar, the Noodles Play Catch-Up',
#      'kicker': '$25 AND UNDER',
#      'content_kicker': None,
#      'print_headline': '$25 AND UNDER; At a Noodle Bar, the Noodles Play Catch-Up',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'glocations',
#       'value': 'New York City',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'MOMOFUKU NOODLE BAR',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Reviews', 'rank': 3, 'major': 'N'},
#      {'name': 'subject', 'value': 'Restaurants', 'rank': 4, 'major': 'N'}],
#     'pub_date': '2005-04-13T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Dining In, Dining Out/Style Desk',
#     'section_name': 'Style',
#     'byline': {'original': 'By Peter Meehan',
#      'person': [{'firstname': 'Peter',
#        'middlename': None,
#        'lastname': 'Meehan',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'Review',
#     '_id': 'nyt://article/cea827ac-5aee-547e-af88-e9e13cbae121',
#     'word_count': 872,
#     'uri': 'nyt://article/cea827ac-5aee-547e-af88-e9e13cbae121'},
#    {'abstract': 'At Kung Fu Little Steamed Buns Ramen in Hell’s Kitchen, the chef’s specialty is as much theater as comfort food.',
#     'web_url': 'https://www.nytimes.com/2014/04/23/dining/hungry-city-kung-fu-little-steamed-buns-ramen-in-hells-kitchen.html',
#     'snippet': 'At Kung Fu Little Steamed Buns Ramen in Hell’s Kitchen, the chef’s specialty is as much theater as comfort food.',
#     'lead_paragraph': 'There is no ramen at Kung Fu Little Steamed Buns Ramen. At least not the kind New Yorkers have come to associate with the word: no roiling Japanese broth, no heady undertow invoking at once the barnyard and the ocean floor.',
#     'print_section': 'D',
#     'print_page': '6',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'A Showman Puts Noodles on Display',
#      'kicker': 'Hungry City',
#      'content_kicker': None,
#      'print_headline': 'A Showman With Noodles',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Restaurants',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'glocations',
#       'value': "Hell's Kitchen (Manhattan, NY)",
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'Kung Fu Little Steamed Buns Ramen (Manhattan, NY, Restaurant)',
#       'rank': 4,
#       'major': 'N'}],
#     'pub_date': '2014-04-17T18:46:35+0000',
#     'document_type': 'article',
#     'news_desk': 'Dining',
#     'section_name': 'Food',
#     'byline': {'original': 'By Ligaya Mishan',
#      'person': [{'firstname': 'Ligaya',
#        'middlename': None,
#        'lastname': 'Mishan',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'Review',
#     '_id': 'nyt://article/333811c5-a483-53d1-87d8-8e0f15029252',
#     'word_count': 697,
#     'uri': 'nyt://article/333811c5-a483-53d1-87d8-8e0f15029252'}],
#   'meta': {'hits': 16297, 'offset': 0, 'time': 38}}}

# %%
# Create an empty list to store the reviews


reviews_list = []

# Loop through pages 0-19
for page_number in range(20):
    # Create a query with a page number
    query_params = {
        'page': page_number,
        "api-key": nyt_api_key,
    }

    # Make a "GET" request and retrieve the JSON
    response = requests.get('https://api.nytimes.com/svc/search/v2/articlesearch.json', params=query_params)

    # Add a twelve-second interval between queries to stay within API query limits
    time.sleep(12)

    if response.status_code == 200:
        reviews = response.json()

        # Try and save the reviews to the reviews_list
        try:
            # Loop through the reviews["response"]["docs"] and append each review to the list
            for review in reviews["response"]["docs"]:
                reviews_list.append(review)
        except KeyError:
            # Print the page that was just retrieved
            print(f"Page {page_number} retrieved successfully.")
    else:
        print(f"Error fetching page {page_number}. Status code: {response.status_code}")
        break 

print(reviews_list)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
preview_results = json.dumps(reviews_list[:5], indent=4)
print(preview_results)
# Out:
# [
#     {
#         "abstract": "Danvers wrestles with her demons. Navarro does, too, but hers appear to be of a different sort.",
#         "web_url": "https://www.nytimes.com/2024/02/04/arts/television/true-detective-recap-episode-4.html",
#         "snippet": "Danvers wrestles with her demons. Navarro does, too, but hers appear to be of a different sort.",
#         "lead_paragraph": "There\u2019s a classic bit on \u201cThe Simpsons\u201d where a panel of children are seated as a focus group for \u201cThe Itchy & Scratchy Show\u201d and asked what they want to see from the long-running cartoon, which has started to flag in the ratings. After an exasperating series of responses, the moderator sums up his findings: \u201cSo you want a realistic, down-to-earth show that\u2019s completely off the wall and swarming with magic robots?\u201d",
#         "source": "The New York Times",
#         "multimedia": [
#             {
#                 "rank": 0,
#                 "subtype": "xlarge",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-articleLarge.jpg",
#                 "height": 401,
#                 "width": 600,
#                 "legacy": {
#                     "xlarge": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-articleLarge.jpg",
#                     "xlargewidth": 600,
#                     "xlargeheight": 401
#                 },
#                 "subType": "xlarge",
#                 "crop_name": "articleLarge"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "popup",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-popup.jpg",
#                 "height": 434,
#                 "width": 650,
#                 "legacy": {},
#                 "subType": "popup",
#                 "crop_name": "popup"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blog480",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-blog480.jpg",
#                 "height": 321,
#                 "width": 480,
#                 "legacy": {},
#                 "subType": "blog480",
#                 "crop_name": "blog480"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blog533",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-blog533.jpg",
#                 "height": 356,
#                 "width": 533,
#                 "legacy": {},
#                 "subType": "blog533",
#                 "crop_name": "blog533"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blog427",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-blog427.jpg",
#                 "height": 285,
#                 "width": 427,
#                 "legacy": {},
#                 "subType": "blog427",
#                 "crop_name": "blog427"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "tmagSF",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-tmagSF.jpg",
#                 "height": 242,
#                 "width": 362,
#                 "legacy": {},
#                 "subType": "tmagSF",
#                 "crop_name": "tmagSF"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "tmagArticle",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-tmagArticle.jpg",
#                 "height": 396,
#                 "width": 592,
#                 "legacy": {},
#                 "subType": "tmagArticle",
#                 "crop_name": "tmagArticle"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "slide",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-slide.jpg",
#                 "height": 401,
#                 "width": 600,
#                 "legacy": {},
#                 "subType": "slide",
#                 "crop_name": "slide"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "jumbo",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-jumbo.jpg",
#                 "height": 684,
#                 "width": 1024,
#                 "legacy": {},
#                 "subType": "jumbo",
#                 "crop_name": "jumbo"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "superJumbo",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-superJumbo.jpg",
#                 "height": 1283,
#                 "width": 1920,
#                 "legacy": {},
#                 "subType": "superJumbo",
#                 "crop_name": "superJumbo"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blog225",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-blog225.jpg",
#                 "height": 150,
#                 "width": 225,
#                 "legacy": {},
#                 "subType": "blog225",
#                 "crop_name": "blog225"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master1050",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-master1050.jpg",
#                 "height": 702,
#                 "width": 1050,
#                 "legacy": {},
#                 "subType": "master1050",
#                 "crop_name": "master1050"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master675",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-master675.jpg",
#                 "height": 451,
#                 "width": 675,
#                 "legacy": {},
#                 "subType": "master675",
#                 "crop_name": "master675"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master495",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-master495.jpg",
#                 "height": 331,
#                 "width": 495,
#                 "legacy": {},
#                 "subType": "master495",
#                 "crop_name": "master495"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master180",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-master180.jpg",
#                 "height": 120,
#                 "width": 180,
#                 "legacy": {},
#                 "subType": "master180",
#                 "crop_name": "master180"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master315",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-master315.jpg",
#                 "height": 210,
#                 "width": 315,
#                 "legacy": {},
#                 "subType": "master315",
#                 "crop_name": "master315"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master768",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-master768.jpg",
#                 "height": 513,
#                 "width": 768,
#                 "legacy": {},
#                 "subType": "master768",
#                 "crop_name": "master768"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "thumbnail",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-thumbStandard.jpg",
#                 "height": 75,
#                 "width": 75,
#                 "legacy": {
#                     "thumbnail": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-thumbStandard.jpg",
#                     "thumbnailwidth": 75,
#                     "thumbnailheight": 75
#                 },
#                 "subType": "thumbnail",
#                 "crop_name": "thumbStandard"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blogSmallThumb",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-blogSmallThumb.jpg",
#                 "height": 50,
#                 "width": 50,
#                 "legacy": {},
#                 "subType": "blogSmallThumb",
#                 "crop_name": "blogSmallThumb"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "thumbLarge",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-thumbLarge.jpg",
#                 "height": 150,
#                 "width": 150,
#                 "legacy": {},
#                 "subType": "thumbLarge",
#                 "crop_name": "thumbLarge"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "smallSquare168",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-smallSquare168.jpg",
#                 "height": 168,
#                 "width": 168,
#                 "legacy": {},
#                 "subType": "smallSquare168",
#                 "crop_name": "smallSquare168"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "smallSquare252",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-smallSquare252.jpg",
#                 "height": 252,
#                 "width": 252,
#                 "legacy": {},
#                 "subType": "smallSquare252",
#                 "crop_name": "smallSquare252"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "square320",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-square320.jpg",
#                 "height": 320,
#                 "width": 320,
#                 "legacy": {},
#                 "subType": "square320",
#                 "crop_name": "square320"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "moth",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-moth.jpg",
#                 "height": 151,
#                 "width": 151,
#                 "legacy": {},
#                 "subType": "moth",
#                 "crop_name": "moth"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "filmstrip",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-filmstrip.jpg",
#                 "height": 190,
#                 "width": 190,
#                 "legacy": {},
#                 "subType": "filmstrip",
#                 "crop_name": "filmstrip"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "square640",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-square640.jpg",
#                 "height": 640,
#                 "width": 640,
#                 "legacy": {},
#                 "subType": "square640",
#                 "crop_name": "square640"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "mediumSquare149",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-mediumSquare149.jpg",
#                 "height": 149,
#                 "width": 149,
#                 "legacy": {},
#                 "subType": "mediumSquare149",
#                 "crop_name": "mediumSquare149"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "mediumSquareAt3X",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-mediumSquareAt3X.jpg",
#                 "height": 1283,
#                 "width": 1283,
#                 "legacy": {},
#                 "subType": "mediumSquareAt3X",
#                 "crop_name": "mediumSquareAt3X"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "sfSpan",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-sfSpan.jpg",
#                 "height": 263,
#                 "width": 395,
#                 "legacy": {},
#                 "subType": "sfSpan",
#                 "crop_name": "sfSpan"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "largeHorizontal375",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-largeHorizontal375.jpg",
#                 "height": 250,
#                 "width": 375,
#                 "legacy": {},
#                 "subType": "largeHorizontal375",
#                 "crop_name": "largeHorizontal375"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "largeHorizontalJumbo",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-largeHorizontalJumbo.jpg",
#                 "height": 683,
#                 "width": 1024,
#                 "legacy": {},
#                 "subType": "largeHorizontalJumbo",
#                 "crop_name": "largeHorizontalJumbo"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "horizontalMediumAt2X",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-horizontalMediumAt2X.jpg",
#                 "height": 1280,
#                 "width": 1920,
#                 "legacy": {},
#                 "subType": "horizontalMediumAt2X",
#                 "crop_name": "horizontalMediumAt2X"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "hpLarge",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-hpLarge.jpg",
#                 "height": 287,
#                 "width": 511,
#                 "legacy": {},
#                 "subType": "hpLarge",
#                 "crop_name": "hpLarge"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "largeWidescreen573",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-largeWidescreen573.jpg",
#                 "height": 322,
#                 "width": 573,
#                 "legacy": {},
#                 "subType": "largeWidescreen573",
#                 "crop_name": "largeWidescreen573"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "largeWidescreen1050",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-largeWidescreen1050.jpg",
#                 "height": 591,
#                 "width": 1050,
#                 "legacy": {},
#                 "subType": "largeWidescreen1050",
#                 "crop_name": "largeWidescreen1050"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "wide",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-thumbWide.jpg",
#                 "height": 126,
#                 "width": 190,
#                 "legacy": {
#                     "widewidth": 190,
#                     "wideheight": 126,
#                     "wide": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-thumbWide.jpg"
#                 },
#                 "subType": "wide",
#                 "crop_name": "thumbWide"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoThumb",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-videoThumb.jpg",
#                 "height": 50,
#                 "width": 75,
#                 "legacy": {},
#                 "subType": "videoThumb",
#                 "crop_name": "videoThumb"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoLarge",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-videoLarge.jpg",
#                 "height": 507,
#                 "width": 768,
#                 "legacy": {},
#                 "subType": "videoLarge",
#                 "crop_name": "videoLarge"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "mediumThreeByTwo210",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-mediumThreeByTwo210.jpg",
#                 "height": 140,
#                 "width": 210,
#                 "legacy": {},
#                 "subType": "mediumThreeByTwo210",
#                 "crop_name": "mediumThreeByTwo210"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "mediumThreeByTwo225",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-mediumThreeByTwo225.jpg",
#                 "height": 150,
#                 "width": 225,
#                 "legacy": {},
#                 "subType": "mediumThreeByTwo225",
#                 "crop_name": "mediumThreeByTwo225"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "mediumThreeByTwo440",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-mediumThreeByTwo440.jpg",
#                 "height": 293,
#                 "width": 440,
#                 "legacy": {},
#                 "subType": "mediumThreeByTwo440",
#                 "crop_name": "mediumThreeByTwo440"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "mediumThreeByTwo252",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-mediumThreeByTwo252.jpg",
#                 "height": 168,
#                 "width": 252,
#                 "legacy": {},
#                 "subType": "mediumThreeByTwo252",
#                 "crop_name": "mediumThreeByTwo252"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "mediumThreeByTwo378",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-mediumThreeByTwo378.jpg",
#                 "height": 252,
#                 "width": 378,
#                 "legacy": {},
#                 "subType": "mediumThreeByTwo378",
#                 "crop_name": "mediumThreeByTwo378"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "threeByTwoLargeAt2X",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-threeByTwoLargeAt2X.jpg",
#                 "height": 1280,
#                 "width": 1920,
#                 "legacy": {},
#                 "subType": "threeByTwoLargeAt2X",
#                 "crop_name": "threeByTwoLargeAt2X"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "threeByTwoMediumAt2X",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-threeByTwoMediumAt2X.jpg",
#                 "height": 1000,
#                 "width": 1500,
#                 "legacy": {},
#                 "subType": "threeByTwoMediumAt2X",
#                 "crop_name": "threeByTwoMediumAt2X"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "threeByTwoSmallAt2X",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-threeByTwoSmallAt2X.jpg",
#                 "height": 400,
#                 "width": 600,
#                 "legacy": {},
#                 "subType": "threeByTwoSmallAt2X",
#                 "crop_name": "threeByTwoSmallAt2X"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "articleInline",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-articleInline.jpg",
#                 "height": 127,
#                 "width": 190,
#                 "legacy": {},
#                 "subType": "articleInline",
#                 "crop_name": "articleInline"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "hpSmall",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-hpSmall.jpg",
#                 "height": 109,
#                 "width": 163,
#                 "legacy": {},
#                 "subType": "hpSmall",
#                 "crop_name": "hpSmall"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blogSmallInline",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-blogSmallInline.jpg",
#                 "height": 101,
#                 "width": 151,
#                 "legacy": {},
#                 "subType": "blogSmallInline",
#                 "crop_name": "blogSmallInline"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "mediumFlexible177",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-mediumFlexible177.jpg",
#                 "height": 118,
#                 "width": 177,
#                 "legacy": {},
#                 "subType": "mediumFlexible177",
#                 "crop_name": "mediumFlexible177"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSmall",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-videoSmall.jpg",
#                 "height": 281,
#                 "width": 500,
#                 "legacy": {},
#                 "subType": "videoSmall",
#                 "crop_name": "videoSmall"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoHpMedium",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-videoHpMedium.jpg",
#                 "height": 211,
#                 "width": 375,
#                 "legacy": {},
#                 "subType": "videoHpMedium",
#                 "crop_name": "videoHpMedium"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine600",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-videoSixteenByNine600.jpg",
#                 "height": 338,
#                 "width": 600,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine600",
#                 "crop_name": "videoSixteenByNine600"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine540",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-videoSixteenByNine540.jpg",
#                 "height": 304,
#                 "width": 540,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine540",
#                 "crop_name": "videoSixteenByNine540"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine495",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-videoSixteenByNine495.jpg",
#                 "height": 278,
#                 "width": 495,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine495",
#                 "crop_name": "videoSixteenByNine495"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine390",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-videoSixteenByNine390.jpg",
#                 "height": 219,
#                 "width": 390,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine390",
#                 "crop_name": "videoSixteenByNine390"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine1050",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-videoSixteenByNine1050.jpg",
#                 "height": 591,
#                 "width": 1050,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine1050",
#                 "crop_name": "videoSixteenByNine1050"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine480",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-videoSixteenByNine480.jpg",
#                 "height": 270,
#                 "width": 480,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine480",
#                 "crop_name": "videoSixteenByNine480"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine310",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-videoSixteenByNine310.jpg",
#                 "height": 174,
#                 "width": 310,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine310",
#                 "crop_name": "videoSixteenByNine310"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine225",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-videoSixteenByNine225.jpg",
#                 "height": 126,
#                 "width": 225,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine225",
#                 "crop_name": "videoSixteenByNine225"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine96",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-videoSixteenByNine96.jpg",
#                 "height": 54,
#                 "width": 96,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine96",
#                 "crop_name": "videoSixteenByNine96"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine768",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-videoSixteenByNine768.jpg",
#                 "height": 432,
#                 "width": 768,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine768",
#                 "crop_name": "videoSixteenByNine768"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine150",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-videoSixteenByNine150.jpg",
#                 "height": 84,
#                 "width": 150,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine150",
#                 "crop_name": "videoSixteenByNine150"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNineJumbo1600",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-videoSixteenByNineJumbo1600.jpg",
#                 "height": 900,
#                 "width": 1600,
#                 "legacy": {},
#                 "subType": "videoSixteenByNineJumbo1600",
#                 "crop_name": "videoSixteenByNineJumbo1600"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "miniMoth",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-miniMoth.jpg",
#                 "height": 70,
#                 "width": 151,
#                 "legacy": {},
#                 "subType": "miniMoth",
#                 "crop_name": "miniMoth"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "windowsTile336H",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-windowsTile336H.jpg",
#                 "height": 336,
#                 "width": 694,
#                 "legacy": {},
#                 "subType": "windowsTile336H",
#                 "crop_name": "windowsTile336H"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoFifteenBySeven1305",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-videoFifteenBySeven1305.jpg",
#                 "height": 609,
#                 "width": 1305,
#                 "legacy": {},
#                 "subType": "videoFifteenBySeven1305",
#                 "crop_name": "videoFifteenBySeven1305"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "facebookJumbo",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-facebookJumbo.jpg",
#                 "height": 550,
#                 "width": 1050,
#                 "legacy": {},
#                 "subType": "facebookJumbo",
#                 "crop_name": "facebookJumbo"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "watch308",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-watch308.jpg",
#                 "height": 348,
#                 "width": 312,
#                 "legacy": {},
#                 "subType": "watch308",
#                 "crop_name": "watch308"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "watch268",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-watch268.jpg",
#                 "height": 303,
#                 "width": 272,
#                 "legacy": {},
#                 "subType": "watch268",
#                 "crop_name": "watch268"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "verticalTwoByThree735",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-verticalTwoByThree735.jpg",
#                 "height": 1103,
#                 "width": 735,
#                 "legacy": {},
#                 "subType": "verticalTwoByThree735",
#                 "crop_name": "verticalTwoByThree735"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "mobileMasterAt3x",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/arts/04true-detective-recap/04true-detective-recap-mobileMasterAt3x.jpg",
#                 "height": 1203,
#                 "width": 1800,
#                 "legacy": {},
#                 "subType": "mobileMasterAt3x",
#                 "crop_name": "mobileMasterAt3x"
#             }
#         ],
#         "headline": {
#             "main": "\u2018True Detective\u2019 Season 4, Episode 4 Recap: The Monster Under the Bed",
#             "kicker": "True Detective",
#             "content_kicker": null,
#             "print_headline": null,
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Television",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "True Detective (TV Program)",
#                 "rank": 2,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2024-02-05T03:01:08+0000",
#         "document_type": "article",
#         "news_desk": "Culture",
#         "section_name": "Arts",
#         "subsection_name": "Television",
#         "byline": {
#             "original": "By Scott Tobias",
#             "person": [
#                 {
#                     "firstname": "Scott",
#                     "middlename": null,
#                     "lastname": "Tobias",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "type_of_material": "Review",
#         "_id": "nyt://article/efb0ace5-305c-56ad-b8a2-267f5078e793",
#         "word_count": 1076,
#         "uri": "nyt://article/efb0ace5-305c-56ad-b8a2-267f5078e793"
#     },
#     {
#         "abstract": "At the end of her tribute to the outspoken artist, Lennox proclaimed: \u201cArtists for cease-fire\u201d",
#         "web_url": "https://www.nytimes.com/2024/02/04/arts/music/annie-lennox-sinead-oconnor-grammys.html",
#         "snippet": "At the end of her tribute to the outspoken artist, Lennox proclaimed: \u201cArtists for cease-fire\u201d",
#         "lead_paragraph": "In an emotional ode to Sinead O\u2019Connor at the Grammys, Annie Lennox performed \u201cNothing Compares 2 U,\u201d the Irish singer-songwriter\u2019s cover of the Prince original that became a No. 1 hit.",
#         "source": "The New York Times",
#         "multimedia": [
#             {
#                 "rank": 0,
#                 "subtype": "xlarge",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04grammys-oconnor-tribute-ptml/04grammys-oconnor-tribute-ptml-articleLarge.jpg",
#                 "height": 400,
#                 "width": 600,
#                 "legacy": {
#                     "xlarge": "images/2024/02/04/multimedia/04grammys-oconnor-tribute-ptml/04grammys-oconnor-tribute-ptml-articleLarge.jpg",
#                     "xlargewidth": 600,
#                     "xlargeheight": 400
#                 },
#                 "subType": "xlarge",
#                 "crop_name": "articleLarge"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "popup",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04grammys-oconnor-tribute-ptml/04grammys-oconnor-tribute-ptml-popup.jpg",
#                 "height": 433,
#                 "width": 650,
#                 "legacy": {},
#                 "subType": "popup",
#                 "crop_name": "popup"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blog480",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04grammys-oconnor-tribute-ptml/04grammys-oconnor-tribute-ptml-blog480.jpg",
#                 "height": 320,
#                 "width": 480,
#                 "legacy": {},
#                 "subType": "blog480",
#                 "crop_name": "blog480"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blog533",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04grammys-oconnor-tribute-ptml/04grammys-oconnor-tribute-ptml-blog533.jpg",
#                 "height": 355,
#                 "width": 533,
#                 "legacy": {},
#                 "subType": "blog533",
#                 "crop_name": "blog533"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blog427",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04grammys-oconnor-tribute-ptml/04grammys-oconnor-tribute-ptml-blog427.jpg",
#                 "height": 284,
#                 "width": 427,
#                 "legacy": {},
#                 "subType": "blog427",
#                 "crop_name": "blog427"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "tmagSF",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04grammys-oconnor-tribute-ptml/04grammys-oconnor-tribute-ptml-tmagSF.jpg",
#                 "height": 241,
#                 "width": 362,
#                 "legacy": {},
#                 "subType": "tmagSF",
#                 "crop_name": "tmagSF"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "tmagArticle",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04grammys-oconnor-tribute-ptml/04grammys-oconnor-tribute-ptml-tmagArticle.jpg",
#                 "height": 394,
#                 "width": 592,
#                 "legacy": {},
#                 "subType": "tmagArticle",
#                 "crop_name": "tmagArticle"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "slide",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04grammys-oconnor-tribute-ptml/04grammys-oconnor-tribute-ptml-slide.jpg",
#                 "height": 400,
#                 "width": 600,
#                 "legacy": {},
#                 "subType": "slide",
#                 "crop_name": "slide"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "jumbo",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04grammys-oconnor-tribute-ptml/04grammys-oconnor-tribute-ptml-jumbo.jpg",
#                 "height": 682,
#                 "width": 1024,
#                 "legacy": {},
#                 "subType": "jumbo",
#                 "crop_name": "jumbo"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "superJumbo",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04grammys-oconnor-tribute-ptml/04grammys-oconnor-tribute-ptml-superJumbo.jpg",
#                 "height": 1364,
#                 "width": 2048,
#                 "legacy": {},
#                 "subType": "superJumbo",
#                 "crop_name": "superJumbo"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blog225",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04grammys-oconnor-tribute-ptml/04grammys-oconnor-tribute-ptml-blog225.jpg",
#                 "height": 150,
#                 "width": 225,
#                 "legacy": {},
#                 "subType": "blog225",
#                 "crop_name": "blog225"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master1050",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04grammys-oconnor-tribute-ptml/04grammys-oconnor-tribute-ptml-master1050.jpg",
#                 "height": 699,
#                 "width": 1050,
#                 "legacy": {},
#                 "subType": "master1050",
#                 "crop_name": "master1050"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master675",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04grammys-oconnor-tribute-ptml/04grammys-oconnor-tribute-ptml-master675.jpg",
#                 "height": 449,
#                 "width": 675,
#                 "legacy": {},
#                 "subType": "master675",
#                 "crop_name": "master675"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master495",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04grammys-oconnor-tribute-ptml/04grammys-oconnor-tribute-ptml-master495.jpg",
#                 "height": 330,
#                 "width": 495,
#                 "legacy": {},
#                 "subType": "master495",
#                 "crop_name": "master495"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master180",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04grammys-oconnor-tribute-ptml/04grammys-oconnor-tribute-ptml-master180.jpg",
#                 "height": 120,
#                 "width": 180,
#                 "legacy": {},
#                 "subType": "master180",
#                 "crop_name": "master180"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master315",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04grammys-oconnor-tribute-ptml/04grammys-oconnor-tribute-ptml-master315.jpg",
#                 "height": 210,
#                 "width": 315,
#                 "legacy": {},
#                 "subType": "master315",
#                 "crop_name": "master315"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "master768",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04grammys-oconnor-tribute-ptml/04grammys-oconnor-tribute-ptml-master768.jpg",
#                 "height": 511,
#                 "width": 768,
#                 "legacy": {},
#                 "subType": "master768",
# ...
#                 "crop_name": "mediumThreeByTwo378"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "threeByTwoLargeAt2X",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04xp-missle-jgvh/04xp-missle-jgvh-threeByTwoLargeAt2X.jpg",
#                 "height": 800,
#                 "width": 1200,
#                 "legacy": {},
#                 "subType": "threeByTwoLargeAt2X",
#                 "crop_name": "threeByTwoLargeAt2X"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "threeByTwoMediumAt2X",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04xp-missle-jgvh/04xp-missle-jgvh-threeByTwoMediumAt2X.jpg",
#                 "height": 800,
#                 "width": 1200,
#                 "legacy": {},
#                 "subType": "threeByTwoMediumAt2X",
#                 "crop_name": "threeByTwoMediumAt2X"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "threeByTwoSmallAt2X",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04xp-missle-jgvh/04xp-missle-jgvh-threeByTwoSmallAt2X.jpg",
#                 "height": 400,
#                 "width": 600,
#                 "legacy": {},
#                 "subType": "threeByTwoSmallAt2X",
#                 "crop_name": "threeByTwoSmallAt2X"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "articleInline",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04xp-missle-jgvh/04xp-missle-jgvh-articleInline.jpg",
#                 "height": 143,
#                 "width": 190,
#                 "legacy": {},
#                 "subType": "articleInline",
#                 "crop_name": "articleInline"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "hpSmall",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04xp-missle-jgvh/04xp-missle-jgvh-hpSmall.jpg",
#                 "height": 122,
#                 "width": 163,
#                 "legacy": {},
#                 "subType": "hpSmall",
#                 "crop_name": "hpSmall"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "blogSmallInline",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04xp-missle-jgvh/04xp-missle-jgvh-blogSmallInline.jpg",
#                 "height": 113,
#                 "width": 151,
#                 "legacy": {},
#                 "subType": "blogSmallInline",
#                 "crop_name": "blogSmallInline"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "mediumFlexible177",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04xp-missle-jgvh/04xp-missle-jgvh-mediumFlexible177.jpg",
#                 "height": 133,
#                 "width": 177,
#                 "legacy": {},
#                 "subType": "mediumFlexible177",
#                 "crop_name": "mediumFlexible177"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSmall",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04xp-missle-jgvh/04xp-missle-jgvh-videoSmall.jpg",
#                 "height": 281,
#                 "width": 500,
#                 "legacy": {},
#                 "subType": "videoSmall",
#                 "crop_name": "videoSmall"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoHpMedium",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04xp-missle-jgvh/04xp-missle-jgvh-videoHpMedium.jpg",
#                 "height": 211,
#                 "width": 375,
#                 "legacy": {},
#                 "subType": "videoHpMedium",
#                 "crop_name": "videoHpMedium"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine600",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04xp-missle-jgvh/04xp-missle-jgvh-videoSixteenByNine600.jpg",
#                 "height": 338,
#                 "width": 600,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine600",
#                 "crop_name": "videoSixteenByNine600"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine540",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04xp-missle-jgvh/04xp-missle-jgvh-videoSixteenByNine540.jpg",
#                 "height": 304,
#                 "width": 540,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine540",
#                 "crop_name": "videoSixteenByNine540"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine495",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04xp-missle-jgvh/04xp-missle-jgvh-videoSixteenByNine495.jpg",
#                 "height": 278,
#                 "width": 495,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine495",
#                 "crop_name": "videoSixteenByNine495"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine390",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04xp-missle-jgvh/04xp-missle-jgvh-videoSixteenByNine390.jpg",
#                 "height": 219,
#                 "width": 390,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine390",
#                 "crop_name": "videoSixteenByNine390"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine1050",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04xp-missle-jgvh/04xp-missle-jgvh-videoSixteenByNine1050.jpg",
#                 "height": 591,
#                 "width": 1050,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine1050",
#                 "crop_name": "videoSixteenByNine1050"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine480",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04xp-missle-jgvh/04xp-missle-jgvh-videoSixteenByNine480.jpg",
#                 "height": 270,
#                 "width": 480,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine480",
#                 "crop_name": "videoSixteenByNine480"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine310",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04xp-missle-jgvh/04xp-missle-jgvh-videoSixteenByNine310.jpg",
#                 "height": 174,
#                 "width": 310,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine310",
#                 "crop_name": "videoSixteenByNine310"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine225",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04xp-missle-jgvh/04xp-missle-jgvh-videoSixteenByNine225.jpg",
#                 "height": 126,
#                 "width": 225,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine225",
#                 "crop_name": "videoSixteenByNine225"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine96",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04xp-missle-jgvh/04xp-missle-jgvh-videoSixteenByNine96.jpg",
#                 "height": 54,
#                 "width": 96,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine96",
#                 "crop_name": "videoSixteenByNine96"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine768",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04xp-missle-jgvh/04xp-missle-jgvh-videoSixteenByNine768.jpg",
#                 "height": 432,
#                 "width": 768,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine768",
#                 "crop_name": "videoSixteenByNine768"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNine150",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04xp-missle-jgvh/04xp-missle-jgvh-videoSixteenByNine150.jpg",
#                 "height": 84,
#                 "width": 150,
#                 "legacy": {},
#                 "subType": "videoSixteenByNine150",
#                 "crop_name": "videoSixteenByNine150"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "videoSixteenByNineJumbo1600",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04xp-missle-jgvh/04xp-missle-jgvh-videoSixteenByNineJumbo1600.jpg",
#                 "height": 675,
#                 "width": 1200,
#                 "legacy": {},
#                 "subType": "videoSixteenByNineJumbo1600",
#                 "crop_name": "videoSixteenByNineJumbo1600"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "miniMoth",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04xp-missle-jgvh/04xp-missle-jgvh-miniMoth.jpg",
#                 "height": 70,
#                 "width": 151,
#                 "legacy": {},
#                 "subType": "miniMoth",
#                 "crop_name": "miniMoth"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "windowsTile336H",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04xp-missle-jgvh/04xp-missle-jgvh-windowsTile336H.jpg",
#                 "height": 336,
#                 "width": 694,
#                 "legacy": {},
#                 "subType": "windowsTile336H",
#                 "crop_name": "windowsTile336H"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "facebookJumbo",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04xp-missle-jgvh/04xp-missle-jgvh-facebookJumbo.jpg",
#                 "height": 550,
#                 "width": 1050,
#                 "legacy": {},
#                 "subType": "facebookJumbo",
#                 "crop_name": "facebookJumbo"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "watch308",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04xp-missle-jgvh/04xp-missle-jgvh-watch308.jpg",
#                 "height": 348,
#                 "width": 312,
#                 "legacy": {},
#                 "subType": "watch308",
#                 "crop_name": "watch308"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "watch268",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04xp-missle-jgvh/04xp-missle-jgvh-watch268.jpg",
#                 "height": 303,
#                 "width": 272,
#                 "legacy": {},
#                 "subType": "watch268",
#                 "crop_name": "watch268"
#             },
#             {
#                 "rank": 0,
#                 "subtype": "mobileMasterAt3x",
#                 "caption": null,
#                 "credit": null,
#                 "type": "image",
#                 "url": "images/2024/02/04/multimedia/04xp-missle-jgvh/04xp-missle-jgvh-mobileMasterAt3x-v2.jpg",
#                 "height": 900,
#                 "width": 1200,
#                 "legacy": {},
#                 "subType": "mobileMasterAt3x",
#                 "crop_name": "mobileMasterAt3x"
#             }
#         ],
#         "headline": {
#             "main": "Remnants of a Nuclear Missile Are Found in a Garage",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": null,
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Nuclear Weapons",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "glocations",
#                 "value": "Dayton (Ohio)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Missiles and Missile Defense Systems",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "United States Defense and Military Forces",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Cold War Era",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "organizations",
#                 "value": "United States Air Force",
#                 "rank": 7,
#                 "major": "N"
#             },
#             {
#                 "name": "glocations",
#                 "value": "Bellevue (Wash)",
#                 "rank": 8,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2024-02-05T01:10:15+0000",
#         "document_type": "article",
#         "news_desk": "Express",
#         "section_name": "U.S.",
#         "byline": {
#             "original": "By Gaya Gupta",
#             "person": [
#                 {
#                     "firstname": "Gaya",
#                     "middlename": null,
#                     "lastname": "Gupta",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "type_of_material": "News",
#         "_id": "nyt://article/c7f2f2d5-8970-5504-86eb-caa25a4d7b90",
#         "word_count": 495,
#         "uri": "nyt://article/c7f2f2d5-8970-5504-86eb-caa25a4d7b90"
#     }
# ]

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
nyt_df = json_normalize(reviews_list)
nyt_df
# Out:
#                                               abstract  \
# 0    Danvers wrestles with her demons. Navarro does...
# 1    At the end of her tribute to the outspoken art...
# 2    During her win for best pop vocal album, the s...
# 3    Her duet with Luke Combs was one of her few pu...
# 4    The police responded to a call from a U.S. Air...
# ..                                                 ...
# 195  The strikes, in response to a drone attack tha...
# 196  Fani T. Willis, the Fulton County, Ga., distri...
# 197  Originally a painter, she worked low-level off...
# 198  For the first time, a Sinn Fein politician wil...
# 199  Our theater critic on some of the Broadway leg...
#
#                                                web_url  \
# 0    https://www.nytimes.com/2024/02/04/arts/televi...
# 1    https://www.nytimes.com/2024/02/04/arts/music/...
# 2    https://www.nytimes.com/2024/02/04/arts/music/...
# 3    https://www.nytimes.com/2024/02/04/arts/music/...
# 4    https://www.nytimes.com/2024/02/04/us/seattle-...
# ..                                                 ...
# 195  https://www.nytimes.com/2024/02/02/us/politics...
# 196  https://www.nytimes.com/interactive/2024/02/02...
# 197  https://www.nytimes.com/2024/02/02/arts/alice-...
# 198  https://www.nytimes.com/2024/02/02/world/europ...
# 199  https://www.nytimes.com/2024/02/02/podcasts/cu...
#
#                                                snippet  \
# 0    Danvers wrestles with her demons. Navarro does...
# 1    At the end of her tribute to the outspoken art...
# 2    During her win for best pop vocal album, the s...
# 3    Her duet with Luke Combs was one of her few pu...
# 4    The police responded to a call from a U.S. Air...
# ..                                                 ...
# 195  The strikes, in response to a drone attack tha...
# 196  Fani T. Willis, the Fulton County, Ga., distri...
# 197  Originally a painter, she worked low-level off...
# 198  For the first time, a Sinn Fein politician wil...
# 199  Our theater critic on some of the Broadway leg...
#
#                                         lead_paragraph              source  \
# 0    There’s a classic bit on “The Simpsons” where ...  The New York Times
# 1    In an emotional ode to Sinead O’Connor at the ...  The New York Times
# 2    As she accepted the Grammy for best pop vocal ...  The New York Times
# 3    In a major coup for the Grammys, an influentia...  The New York Times
# 4    Garages are often cluttered with dusty boxes o...  The New York Times
# ..                                                 ...                 ...
# 195  The United States on Friday carried out a seri...  The New York Times
# 196  Fani T. Willis, the Fulton County, Ga., distri...  The New York Times
# 197  Alice Mackler, who toiled in obscurity as a pa...  The New York Times
# 198  After two years of political gridlock, Norther...  The New York Times
# 199  Chita Rivera died on Jan. 30, at age 91. Over ...  The New York Times
#
#                                             multimedia  \
# 0    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 1    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 3    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 4    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# ..                                                 ...
# 195  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 196  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 197  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 198  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 199  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
#
#                                               keywords  \
# 0    [{'name': 'subject', 'value': 'Television', 'r...
# 1    [{'name': 'subject', 'value': 'Pop and Rock Mu...
# 2    [{'name': 'subject', 'value': 'Pop and Rock Mu...
# 3    [{'name': 'subject', 'value': 'Music', 'rank':...
# 4    [{'name': 'subject', 'value': 'Nuclear Weapons...
# ..                                                 ...
# 195  [{'name': 'glocations', 'value': 'Iraq', 'rank...
# 196                                                 []
# 197  [{'name': 'subject', 'value': 'Deaths (Obituar...
# 198  [{'name': 'subject', 'value': 'Good Friday Agr...
# 199  [{'name': 'subject', 'value': 'Culture (Arts)'...
#
#                      pub_date document_type   news_desk  ...  \
# 0    2024-02-05T03:01:08+0000       article     Culture  ...
# 1    2024-02-05T02:54:38+0000       article     Culture  ...
# 2    2024-02-05T02:49:32+0000       article     Culture  ...
# 3    2024-02-05T01:30:47+0000       article     Culture  ...
# 4    2024-02-05T01:10:15+0000       article     Express  ...
# ..                        ...           ...         ...  ...
# 195  2024-02-02T21:12:02+0000       article  Washington  ...
# 196  2024-02-02T21:12:02+0000    multimedia        U.S.  ...
# 197  2024-02-02T21:02:53+0000       article       Obits  ...
# 198  2024-02-02T20:41:45+0000       article     Foreign  ...
# 199  2024-02-02T20:36:44+0000       article    Podcasts  ...
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 195                    None
# 196                    None
# 197                    None
# 198                    None
# 199                    None
#
#                                headline.print_headline headline.name  \
# 0                                                 None          None
# 1                                                 None          None
# 2                                                 None          None
# 3                                                 None          None
# 4                                                 None          None
# ..                                                 ...           ...
# 195  U.S. Strikes Back At Iranian Forces In Syria A...          None
# 196                                               None          None
# 197                                               None          None
# 198  After Two-Year Hiatus, Power-Sharing Making Co...          None
# 199                                               None          None
#
#     headline.seo  headline.sub  \
# 0           None          None
# 1           None          None
# 2           None          None
# 3           None          None
# 4           None          None
# ..           ...           ...
# 195         None          None
# 196         None          None
# 197         None          None
# 198         None          None
# 199         None          None
#
#                                        byline.original  \
# 0                                      By Scott Tobias
# 1                                      By Julia Jacobs
# 2                                   By Christopher Kuo
# 3                                        By Marc Hogan
# 4                                        By Gaya Gupta
# ..                                                 ...
# 195  By Helene Cooper, Eric Schmitt and Julian E. B...
# 196                                               None
# 197                                   By Will Heinrich
# 198                                  By Stephen Castle
# 199  By Alex Barron, Lynn Levy, Diane Wong and Jess...
#
#                                          byline.person byline.organization  \
# 0    [{'firstname': 'Scott', 'middlename': None, 'l...                None
# 1    [{'firstname': 'Julia', 'middlename': None, 'l...                None
# 2    [{'firstname': 'Christopher', 'middlename': No...                None
# 3    [{'firstname': 'Marc', 'middlename': None, 'la...                None
# 4    [{'firstname': 'Gaya', 'middlename': None, 'la...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'Helene', 'middlename': None, '...                None
# 196                                                 []                None
# 197  [{'firstname': 'Will', 'middlename': None, 'la...                None
# 198  [{'firstname': 'Stephen', 'middlename': None, ...                None
# 199  [{'firstname': 'Alex', 'middlename': None, 'la...                None
#
#     print_section print_page
# 0             NaN        NaN
# 1             NaN        NaN
# 2             NaN        NaN
# 3             NaN        NaN
# 4             NaN        NaN
# ..            ...        ...
# 195             A          1
# 196           NaN        NaN
# 197           NaN        NaN
# 198           NaN        NaN
# 199           NaN        NaN
#
# [200 rows x 28 columns]

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early
def extract_title(headline):
    match = re.search(r'\u2018(.*?)\u2019', headline)
    if match:
        return match.group(1).strip() + " Review"
    else:
        return None


nyt_df['title'] = nyt_df['headline.main'].apply(extract_title)


print(nyt_df[['headline.main', 'title']])
# Out:
#                                          headline.main                  title
# 0    ‘True Detective’ Season 4, Episode 4 Recap: Th...  True Detective Review
# 1    Annie Lennox Honors Sinead O’Connor With Power...                   None
# 2    Taylor Swift Announces New Album During Grammy...                   None
# 3    Tracy Chapman Returns to the Grammy Stage for ...        Fast Car Review
# 4    Remnants of a Nuclear Missile Are Found in a G...                   None
# ..                                                 ...                    ...
# 195  U.S. Conducts Retaliatory Strikes Against Iran...                   None
# 196                   Read the Filing From Fani Willis                   None
# 197  Alice Mackler, Sculptor Discovered in Her 80s,...                   None
# 198  What to Know About the Return of Power-Sharing...                   None
# 199            Remembering Chita Rivera’s Unique Voice                   None
#
# [200 rows x 2 columns]

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']}; "
        # Append the keyword item to the extracted_keywords string
        extracted_keywords += keyword
    return extracted_keywords.strip()

# Apply the function to create a new "keywords_str" column
nyt_df['keywords_str'] = nyt_df['keywords'].apply(extract_keywords)

# Print the DataFrame to check the results
print(nyt_df[['keywords', 'keywords_str']])
# Out:
#                                               keywords  \
# 0    [{'name': 'subject', 'value': 'Television', 'r...
# 1    [{'name': 'subject', 'value': 'Pop and Rock Mu...
# 2    [{'name': 'subject', 'value': 'Pop and Rock Mu...
# 3    [{'name': 'subject', 'value': 'Music', 'rank':...
# 4    [{'name': 'subject', 'value': 'Nuclear Weapons...
# ..                                                 ...
# 195  [{'name': 'glocations', 'value': 'Iraq', 'rank...
# 196                                                 []
# 197  [{'name': 'subject', 'value': 'Deaths (Obituar...
# 198  [{'name': 'subject', 'value': 'Good Friday Agr...
# 199  [{'name': 'subject', 'value': 'Culture (Arts)'...
#
#                                           keywords_str
# 0    subject: Television; creative_works: True Dete...
# 1    subject: Pop and Rock Music; subject: Grammy A...
# 2    subject: Pop and Rock Music; persons: Swift, T...
# 3    subject: Music; subject: Country Music; person...
# 4    subject: Nuclear Weapons; glocations: Dayton (...
# ..                                                 ...
# 195  glocations: Iraq; glocations: Syria; subject: ...
# 196
# 197  subject: Deaths (Obituaries); subject: Art; su...
# 198  subject: Good Friday Agreement (1998); subject...
# 199  subject: Culture (Arts); persons: Rivera, Chit...
#
# [200 rows x 2 columns]

# %%
# Create a list from the "title" column
titles_list = nyt_df['title'].to_list()

# Print the list to check the results
print(titles_list)
# Out:
# ['True Detective Review', None, None, 'Fast Car Review', None, None, None, 'Barbie Review', None, 'Good Review', None, None, 'Some Like It Hot Review', None, None, None, None, None, None, None, None, None, None, None, 'Bark of Millions Review', None, 'We Review', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'They Come in Waves Review', None, None, 'I Take a Long, Deep, Wild Draught on Your Lips Review', None, None, 'Rock Review', None, None, None, None, None, None, None, 'It Turned Out That We Lived About 10 Blocks From Each Other Review', None, None, None, None, None, None, None, None, 'Dalifornia, Review', None, None, None, None, None, None, None, None, None, None, None, 'Invasion Review', None, None, None, None, None, None, None, None, None, None, None, None, None, 'If Destruction Be Our Lot, We Must Ourselves Be Its Author and Finisher Review', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'Boysober Review', None, None, 'My Heart Sank Review', 'American Fiction Review', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'White Lotus Review', None, None, None, None, None, None, None, None, None, None, None, None, None, 'Mean Girls Review', 'Poor Things Review', None, None, None, None, None, None, None, None, None, None, None, None, None, 'Life-Threatening Flooding Review', None, None, None, None, None, None, None, None, None, None, None, None]

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key

# %%
# Loop through the titles
for title in titles_list:
    # Check if title is not None
    if title:
        # Check if we need to sleep before making a request
        if request_counter % 50 == 0 and request_counter != 0:
            time.sleep(10)  # Sleep for 10 seconds after every 50 requests

        # Add 1 to the request counter
        request_counter += 1

        # Perform a "GET" request for The Movie Database
        response_tmdb = requests.get(url + title.replace(" ", "%20") + tmdb_key_string)

        # Include a try clause to search for the full movie details.
        # Use the except clause to print out a statement if a movie
        # is not found.
        try:
            # Get movie id
            movie_id = response_tmdb.json()["results"][0]["id"]

            # Make a request for the full movie details
            response_full_movie = requests.get(f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb_api_key}")

            # Execute "GET" request with url
            if response_full_movie.status_code == 200:
                full_movie_data = response_full_movie.json()

                # Extract the genre names into a list
                genres_list = [genre["name"] for genre in full_movie_data.get("genres", [])]

                # Extract the spoken_languages' English name into a list
                spoken_languages_list = [lang["english_name"] for lang in full_movie_data.get("spoken_languages", [])]

                # Extract the production_countries' name into a list
                production_countries_list = [country["name"] for country in full_movie_data.get("production_countries", [])]

                # Add the relevant data to a dictionary and
                # append it to the tmdb_movies_list list
                movie_info = {
                    "title": title,
                    "genres": genres_list,
                    "spoken_languages": spoken_languages_list,
                    "production_countries": production_countries_list
                }
                tmdb_movies_list.append(movie_info)

                # Print out the title that was found
                logging.info(f"Movie details found for: {title}")

            else:
                logging.error(f"Error fetching full movie details for {title}. Status code: {response_full_movie.status_code}")

        except (IndexError, KeyError) as e:
            logging.error(f"Error processing details for: {title}. Error: {e}")

# Print the list of movie details
print(tmdb_movies_list)
# Out:
# ERROR:root:Error processing details for: True Detective Review. Error: list index out of range
# ERROR:root:Error processing details for: Fast Car Review. Error: list index out of range
# ERROR:root:Error processing details for: Barbie Review. Error: list index out of range
# INFO:root:Movie details found for: Good Review
# ERROR:root:Error processing details for: Some Like It Hot Review. Error: list index out of range
# ERROR:root:Error processing details for: Bark of Millions Review. Error: list index out of range
# INFO:root:Movie details found for: We Review
# ERROR:root:Error processing details for: They Come in Waves Review. Error: list index out of range
# ERROR:root:Error processing details for: I Take a Long, Deep, Wild Draught on Your Lips Review. Error: list index out of range
# INFO:root:Movie details found for: Rock Review
# ERROR:root:Error processing details for: It Turned Out That We Lived About 10 Blocks From Each Other Review. Error: list index out of range
# ERROR:root:Error processing details for: Dalifornia, Review. Error: list index out of range
# ERROR:root:Error processing details for: Invasion Review. Error: list index out of range
# ERROR:root:Error processing details for: If Destruction Be Our Lot, We Must Ourselves Be Its Author and Finisher Review. Error: list index out of range
# ERROR:root:Error processing details for: Boysober Review. Error: list index out of range
# ERROR:root:Error processing details for: My Heart Sank Review. Error: list index out of range
# ERROR:root:Error processing details for: American Fiction Review. Error: list index out of range
# ERROR:root:Error processing details for: White Lotus Review. Error: list index out of range
# ERROR:root:Error processing details for: Mean Girls Review. Error: list index out of range
# ERROR:root:Error processing details for: Poor Things Review. Error: list index out of range
# ERROR:root:Error processing details for: Life-Threatening Flooding Review. Error: list index out of range
# [{'title': 'Good Review', 'genres': [], 'spoken_languages': ['English'], 'production_countries': []}, {'title': 'We Review', 'genres': [], 'spoken_languages': [], 'production_countries': []}, {'title': 'Rock Review', 'genres': [], 'spoken_languages': [], 'production_countries': []}, {'title': 'Good Review', 'genres': [], 'spoken_languages': ['English'], 'production_countries': []}, {'title': 'We Review', 'genres': [], 'spoken_languages': [], 'production_countries': []}, {'title': 'Rock Review', 'genres': [], 'spoken_languages': [], 'production_countries': []}]

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
preview_results = json.dumps(tmdb_movies_list[:5], indent=4)
print(preview_results)
# Out:
# [
#     {
#         "title": "Good Review",
#         "genres": [],
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": []
#     },
#     {
#         "title": "We Review",
#         "genres": [],
#         "spoken_languages": [],
#         "production_countries": []
#     },
#     {
#         "title": "Rock Review",
#         "genres": [],
#         "spoken_languages": [],
#         "production_countries": []
#     },
#     {
#         "title": "Good Review",
#         "genres": [],
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": []
#     },
#     {
#         "title": "We Review",
#         "genres": [],
#         "spoken_languages": [],
#         "production_countries": []
#     }
# ]

# %%
# Convert the results to a DataFrame
tmdb_df = pd.DataFrame(tmdb_movies_list)

# Display the DataFrame
tmdb_df.head()
# Out:
#          title genres spoken_languages production_countries
# 0  Good Review     []        [English]                   []
# 1    We Review     []               []                   []
# 2  Rock Review     []               []                   []
# 3  Good Review     []        [English]                   []
# 4    We Review     []               []                   []

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
merged_df = pd.merge(nyt_df, tmdb_df, on='title', how='inner')

# Display the merged DataFrame
print(merged_df)
# Out:
#                                             abstract  \
# 0  Federal Reserve officials are debating when to...
# 1  Federal Reserve officials are debating when to...
# 2  Officials are warning of major destruction and...
# 3  Officials are warning of major destruction and...
# 4  Deployed to Djibouti, Maj. Michael Haley has m...
# 5  Deployed to Djibouti, Maj. Michael Haley has m...
#
#                                              web_url  \
# 0  https://www.nytimes.com/2024/02/04/business/ec...
# 1  https://www.nytimes.com/2024/02/04/business/ec...
# 2  https://www.nytimes.com/2024/02/04/world/ameri...
# 3  https://www.nytimes.com/2024/02/04/world/ameri...
# 4  https://www.nytimes.com/2024/02/04/us/politics...
# 5  https://www.nytimes.com/2024/02/04/us/politics...
#
#                                              snippet  \
# 0  Federal Reserve officials are debating when to...
# 1  Federal Reserve officials are debating when to...
# 2  Officials are warning of major destruction and...
# 3  Officials are warning of major destruction and...
# 4  Deployed to Djibouti, Maj. Michael Haley has m...
# 5  Deployed to Djibouti, Maj. Michael Haley has m...
#
#                                       lead_paragraph              source  \
# 0  Jerome H. Powell, the chair of the Federal Res...  The New York Times
# 1  Jerome H. Powell, the chair of the Federal Res...  The New York Times
# 2  Days after devastating wildfires ripped throug...  The New York Times
# 3  Days after devastating wildfires ripped throug...  The New York Times
# 4  When Nikki Haley conceded her deflating third-...  The New York Times
# 5  When Nikki Haley conceded her deflating third-...  The New York Times
#
#                                           multimedia  \
# 0  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 1  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2                                                 []
# 3                                                 []
# 4  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 5  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
#
#                                             keywords  \
# 0  [{'name': 'persons', 'value': 'Powell, Jerome ...
# 1  [{'name': 'persons', 'value': 'Powell, Jerome ...
# 2  [{'name': 'subject', 'value': 'Fires and Firef...
# 3  [{'name': 'subject', 'value': 'Fires and Firef...
# 4  [{'name': 'subject', 'value': 'Presidential El...
# 5  [{'name': 'subject', 'value': 'Presidential El...
#
#                    pub_date document_type news_desk  ...  \
# 0  2024-02-05T00:01:04+0000       article  Business  ...
# 1  2024-02-05T00:01:04+0000       article  Business  ...
# 2  2024-02-04T17:17:20+0000       article   Foreign  ...
# 3  2024-02-04T17:17:20+0000       article   Foreign  ...
# 4  2024-02-04T10:01:02+0000       article  Politics  ...
# 5  2024-02-04T10:01:02+0000       article  Politics  ...
#
#                           byline.original  \
# 0                       By Jeanna Smialek
# 1                       By Jeanna Smialek
# 2      By Annie Correal and John Bartlett
# 3      By Annie Correal and John Bartlett
# 4  By Ken Bensinger and Matthew Rosenberg
# 5  By Ken Bensinger and Matthew Rosenberg
#
#                                        byline.person byline.organization  \
# 0  [{'firstname': 'Jeanna', 'middlename': None, '...                None
# 1  [{'firstname': 'Jeanna', 'middlename': None, '...                None
# 2  [{'firstname': 'Annie', 'middlename': None, 'l...                None
# 3  [{'firstname': 'Annie', 'middlename': None, 'l...                None
# 4  [{'firstname': 'Ken', 'middlename': None, 'las...                None
# 5  [{'firstname': 'Ken', 'middlename': None, 'las...                None
#
#   print_section  print_page        title  \
# 0             B           5  Good Review
# 1             B           5  Good Review
# 2             A           9    We Review
# 3             A           9    We Review
# 4           NaN         NaN  Rock Review
# 5           NaN         NaN  Rock Review
#
#                                         keywords_str genres spoken_languages  \
# 0  persons: Powell, Jerome H; subject: Interest R...     []        [English]
# 1  persons: Powell, Jerome H; subject: Interest R...     []        [English]
# 2  subject: Fires and Firefighters; subject: Wild...     []               []
# 3  subject: Fires and Firefighters; subject: Wild...     []               []
# 4  subject: Presidential Election of 2024; subjec...     []               []
# 5  subject: Presidential Election of 2024; subjec...     []               []
#
#   production_countries
# 0                   []
# 1                   []
# 2                   []
# 3                   []
# 4                   []
# 5                   []
#
# [6 rows x 33 columns]

# %%
# Create a list of the columns that need fixing
columns_to_fix = ['genres', 'spoken_languages', 'production_countries']

# Create a list of characters to remove
characters_to_remove = ["[", "]", "'", '"']

# Loop through the list of columns to fix
for column in columns_to_fix:
    # Convert the column to type 'str'
    merged_df[column] = merged_df[column].astype(str)

    # Loop through characters to remove
    for char in characters_to_remove:
        merged_df[column] = merged_df[column].str.replace(char, '')

# Display the fixed DataFrame
merged_df.head()
# Out:
#                                             abstract  \
# 0  Federal Reserve officials are debating when to...
# 1  Federal Reserve officials are debating when to...
# 2  Officials are warning of major destruction and...
# 3  Officials are warning of major destruction and...
# 4  Deployed to Djibouti, Maj. Michael Haley has m...
#
#                                              web_url  \
# 0  https://www.nytimes.com/2024/02/04/business/ec...
# 1  https://www.nytimes.com/2024/02/04/business/ec...
# 2  https://www.nytimes.com/2024/02/04/world/ameri...
# 3  https://www.nytimes.com/2024/02/04/world/ameri...
# 4  https://www.nytimes.com/2024/02/04/us/politics...
#
#                                              snippet  \
# 0  Federal Reserve officials are debating when to...
# 1  Federal Reserve officials are debating when to...
# 2  Officials are warning of major destruction and...
# 3  Officials are warning of major destruction and...
# 4  Deployed to Djibouti, Maj. Michael Haley has m...
#
#                                       lead_paragraph              source  \
# 0  Jerome H. Powell, the chair of the Federal Res...  The New York Times
# 1  Jerome H. Powell, the chair of the Federal Res...  The New York Times
# 2  Days after devastating wildfires ripped throug...  The New York Times
# 3  Days after devastating wildfires ripped throug...  The New York Times
# 4  When Nikki Haley conceded her deflating third-...  The New York Times
#
#                                           multimedia  \
# 0  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 1  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2                                                 []
# 3                                                 []
# 4  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
#
#                                             keywords  \
# 0  [{'name': 'persons', 'value': 'Powell, Jerome ...
# 1  [{'name': 'persons', 'value': 'Powell, Jerome ...
# 2  [{'name': 'subject', 'value': 'Fires and Firef...
# 3  [{'name': 'subject', 'value': 'Fires and Firef...
# 4  [{'name': 'subject', 'value': 'Presidential El...
#
#                    pub_date document_type news_desk  ...  \
# 0  2024-02-05T00:01:04+0000       article  Business  ...
# 1  2024-02-05T00:01:04+0000       article  Business  ...
# 2  2024-02-04T17:17:20+0000       article   Foreign  ...
# 3  2024-02-04T17:17:20+0000       article   Foreign  ...
# 4  2024-02-04T10:01:02+0000       article  Politics  ...
#
#                           byline.original  \
# 0                       By Jeanna Smialek
# 1                       By Jeanna Smialek
# 2      By Annie Correal and John Bartlett
# 3      By Annie Correal and John Bartlett
# 4  By Ken Bensinger and Matthew Rosenberg
#
#                                        byline.person byline.organization  \
# 0  [{'firstname': 'Jeanna', 'middlename': None, '...                None
# 1  [{'firstname': 'Jeanna', 'middlename': None, '...                None
# 2  [{'firstname': 'Annie', 'middlename': None, 'l...                None
# 3  [{'firstname': 'Annie', 'middlename': None, 'l...                None
# 4  [{'firstname': 'Ken', 'middlename': None, 'las...                None
#
#   print_section  print_page        title  \
# 0             B           5  Good Review
# 1             B           5  Good Review
# 2             A           9    We Review
# 3             A           9    We Review
# 4           NaN         NaN  Rock Review
#
#                                         keywords_str genres spoken_languages  \
# 0  persons: Powell, Jerome H; subject: Interest R...                 English
# 1  persons: Powell, Jerome H; subject: Interest R...                 English
# 2  subject: Fires and Firefighters; subject: Wild...
# 3  subject: Fires and Firefighters; subject: Wild...
# 4  subject: Presidential Election of 2024; subjec...
#
#   production_countries
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 33 columns]

# %%
# Check the columns of the DataFrame
print(merged_df.columns)

# Drop "byline.person" column using the correct indexing approach
merged_df = merged_df.drop(columns=['byline.person'])

# Display the updated DataFrame
merged_df.head()
# Out:
# Index(['abstract', 'web_url', 'snippet', 'lead_paragraph', 'source',
#        'multimedia', 'keywords', 'pub_date', 'document_type', 'news_desk',
#        'section_name', 'subsection_name', 'type_of_material', '_id',
#        'word_count', 'uri', 'headline.main', 'headline.kicker',
#        'headline.content_kicker', 'headline.print_headline', 'headline.name',
#        'headline.seo', 'headline.sub', 'byline.original', 'byline.person',
#        'byline.organization', 'print_section', 'print_page', 'title',
#        'keywords_str', 'genres', 'spoken_languages', 'production_countries'],
#       dtype='object')
#                                             abstract  \
# 0  Federal Reserve officials are debating when to...
# 1  Federal Reserve officials are debating when to...
# 2  Officials are warning of major destruction and...
# 3  Officials are warning of major destruction and...
# 4  Deployed to Djibouti, Maj. Michael Haley has m...
#
#                                              web_url  \
# 0  https://www.nytimes.com/2024/02/04/business/ec...
# 1  https://www.nytimes.com/2024/02/04/business/ec...
# 2  https://www.nytimes.com/2024/02/04/world/ameri...
# 3  https://www.nytimes.com/2024/02/04/world/ameri...
# 4  https://www.nytimes.com/2024/02/04/us/politics...
#
#                                              snippet  \
# 0  Federal Reserve officials are debating when to...
# 1  Federal Reserve officials are debating when to...
# 2  Officials are warning of major destruction and...
# 3  Officials are warning of major destruction and...
# 4  Deployed to Djibouti, Maj. Michael Haley has m...
#
#                                       lead_paragraph              source  \
# 0  Jerome H. Powell, the chair of the Federal Res...  The New York Times
# 1  Jerome H. Powell, the chair of the Federal Res...  The New York Times
# 2  Days after devastating wildfires ripped throug...  The New York Times
# 3  Days after devastating wildfires ripped throug...  The New York Times
# 4  When Nikki Haley conceded her deflating third-...  The New York Times
#
#                                           multimedia  \
# 0  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 1  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2                                                 []
# 3                                                 []
# 4  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
#
#                                             keywords  \
# 0  [{'name': 'persons', 'value': 'Powell, Jerome ...
# 1  [{'name': 'persons', 'value': 'Powell, Jerome ...
# 2  [{'name': 'subject', 'value': 'Fires and Firef...
# 3  [{'name': 'subject', 'value': 'Fires and Firef...
# 4  [{'name': 'subject', 'value': 'Presidential El...
#
#                    pub_date document_type news_desk  ... headline.sub  \
# 0  2024-02-05T00:01:04+0000       article  Business  ...         None
# 1  2024-02-05T00:01:04+0000       article  Business  ...         None
# 2  2024-02-04T17:17:20+0000       article   Foreign  ...         None
# 3  2024-02-04T17:17:20+0000       article   Foreign  ...         None
# 4  2024-02-04T10:01:02+0000       article  Politics  ...         None
#
#                           byline.original byline.organization print_section  \
# 0                       By Jeanna Smialek                None             B
# 1                       By Jeanna Smialek                None             B
# 2      By Annie Correal and John Bartlett                None             A
# 3      By Annie Correal and John Bartlett                None             A
# 4  By Ken Bensinger and Matthew Rosenberg                None           NaN
#
#    print_page        title                                       keywords_str  \
# 0           5  Good Review  persons: Powell, Jerome H; subject: Interest R...
# 1           5  Good Review  persons: Powell, Jerome H; subject: Interest R...
# 2           9    We Review  subject: Fires and Firefighters; subject: Wild...
# 3           9    We Review  subject: Fires and Firefighters; subject: Wild...
# 4         NaN  Rock Review  subject: Presidential Election of 2024; subjec...
#
#   genres spoken_languages production_countries
# 0                 English
# 1                 English
# 2
# 3
# 4
#
# [5 rows x 32 columns]

# %%
# Delete duplicate rows
merged_df = merged_df.apply(str)
merged_df = merged_df.drop_duplicates()
updated_merged_df = pd.DataFrame(merged_df)
# Reset index
updated_merged_df = updated_merged_df.reset_index(drop=True)

# Display the updated DataFrame
updated_merged_df.head
# Out:
# <bound method NDFrame.head of                                                     0
# 0   0    Federal Reserve officials are debating wh...
# 1   0    https://www.nytimes.com/2024/02/04/busine...
# 2   0    Federal Reserve officials are debating wh...
# 3   0    Jerome H. Powell, the chair of the Federa...
# 4   0    The New York Times\n1    The New York Tim...
# 5   0    [{'rank': 0, 'subtype': 'xlarge', 'captio...
# 6   0    [{'name': 'persons', 'value': 'Powell, Je...
# 7   0    2024-02-05T00:01:04+0000\n1    2024-02-05...
# 8   0    article\n1    article\n2    article\n3   ...
# 9   0    Business\n1    Business\n2     Foreign\n3...
# 10  0    Business Day\n1    Business Day\n2       ...
# 11  0     Economy\n1     Economy\n2    Americas\n3...
# 12  0    News\n1    News\n2    News\n3    News\n4 ...
# 13  0    nyt://article/81ee1331-3bbb-5b14-a491-91c...
# 14  0     604\n1     604\n2    1222\n3    1222\n4 ...
# 15  0    nyt://article/81ee1331-3bbb-5b14-a491-91c...
# 16  0    Fed Chair Powell Says Officials Need More...
# 17  0    None\n1    None\n2    None\n3    None\n4 ...
# 18  0    None\n1    None\n2    None\n3    None\n4 ...
# 19  0    Fed Chair Signals Interest Rate Cuts Are ...
# 20  0    None\n1    None\n2    None\n3    None\n4 ...
# 21  0    None\n1    None\n2    None\n3    None\n4 ...
# 22  0    None\n1    None\n2    None\n3    None\n4 ...
# 23  0                         By Jeanna Smialek\n1...
# 24  0    None\n1    None\n2    None\n3    None\n4 ...
# 25  0      B\n1      B\n2      A\n3      A\n4    N...
# 26  0      5\n1      5\n2      9\n3      9\n4    N...
# 27  0    Good Review\n1    Good Review\n2      We ...
# 28  0    persons: Powell, Jerome H; subject: Inter...
# 29  0    \n1    \n2    \n3    \n4    \n5    \nName...
# 30  0    English\n1    English\n2           \n3   ...
# 31  0    \n1    \n2    \n3    \n4    \n5    \nName...>

# %%
# Export data to CSV without the index
updated_merged_df.to_csv('your_file.csv', index=False)
